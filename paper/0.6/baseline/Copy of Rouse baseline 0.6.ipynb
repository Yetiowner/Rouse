# %%
# !git clone https://github.com/Yetiowner/Rouse
# !cd Rouse
# !python Rouse/setup.py install
# Out:
# Cloning into 'Rouse'...
# remote: Enumerating objects: 379, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 379 (delta 25), reused 38 (delta 10), pack-reused 325
# Receiving objects: 100% (379/379), 20.01 MiB | 22.95 MiB/s, done.
# Resolving deltas: 100% (230/230), done.
# running install
# /usr/local/lib/python3.9/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/setuptools/command/easy_install.py:144: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# running bdist_egg
# running egg_info
# creating Rouse.egg-info
# writing Rouse.egg-info/PKG-INFO
# writing dependency_links to Rouse.egg-info/dependency_links.txt
# writing requirements to Rouse.egg-info/requires.txt
# writing top-level names to Rouse.egg-info/top_level.txt
# writing manifest file 'Rouse.egg-info/SOURCES.txt'
# reading manifest file 'Rouse.egg-info/SOURCES.txt'
# writing manifest file 'Rouse.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/Rouse
# copying Rouse/test.py -> build/lib/Rouse
# copying Rouse/unpickleds.py -> build/lib/Rouse
# copying Rouse/modelResNet.py -> build/lib/Rouse
# copying Rouse/__init__.py -> build/lib/Rouse
# copying Rouse/setup.py -> build/lib/Rouse
# copying Rouse/dataClean.py -> build/lib/Rouse
# copying Rouse/usage.py -> build/lib/Rouse
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/Rouse
# copying build/lib/Rouse/test.py -> build/bdist.linux-x86_64/egg/Rouse
# copying build/lib/Rouse/unpickleds.py -> build/bdist.linux-x86_64/egg/Rouse
# copying build/lib/Rouse/modelResNet.py -> build/bdist.linux-x86_64/egg/Rouse
# copying build/lib/Rouse/__init__.py -> build/bdist.linux-x86_64/egg/Rouse
# copying build/lib/Rouse/setup.py -> build/bdist.linux-x86_64/egg/Rouse
# copying build/lib/Rouse/dataClean.py -> build/bdist.linux-x86_64/egg/Rouse
# copying build/lib/Rouse/usage.py -> build/bdist.linux-x86_64/egg/Rouse
# byte-compiling build/bdist.linux-x86_64/egg/Rouse/test.py to test.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/Rouse/unpickleds.py to unpickleds.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/Rouse/modelResNet.py to modelResNet.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/Rouse/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/Rouse/setup.py to setup.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/Rouse/dataClean.py to dataClean.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/Rouse/usage.py to usage.cpython-39.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying Rouse.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying Rouse.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying Rouse.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying Rouse.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying Rouse.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating dist
# creating 'dist/Rouse-0.1-py3.9.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing Rouse-0.1-py3.9.egg
# Copying Rouse-0.1-py3.9.egg to /usr/local/lib/python3.9/dist-packages
# Adding Rouse 0.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.9/dist-packages/Rouse-0.1-py3.9.egg
# Processing dependencies for Rouse==0.1
# Searching for tensorflow==2.12.0
# Best match: tensorflow 2.12.0
# Adding tensorflow 2.12.0 to easy-install.pth file
# Installing estimator_ckpt_converter script to /usr/local/bin
# Installing import_pb_to_tensorboard script to /usr/local/bin
# Installing saved_model_cli script to /usr/local/bin
# Installing tensorboard script to /usr/local/bin
# Installing tf_upgrade_v2 script to /usr/local/bin
# Installing tflite_convert script to /usr/local/bin
# Installing toco script to /usr/local/bin
# Installing toco_from_protos script to /usr/local/bin
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for numpy==1.22.4
# Best match: numpy 1.22.4
# Adding numpy 1.22.4 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.9 script to /usr/local/bin
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for matplotlib==3.7.1
# Best match: matplotlib 3.7.1
# Adding matplotlib 3.7.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for opencv-python==4.7.0.72
# Best match: opencv-python 4.7.0.72
# Adding opencv-python 4.7.0.72 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for keras==2.12.0
# Best match: keras 2.12.0
# Adding keras 2.12.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for tensorflow-io-gcs-filesystem==0.32.0
# Best match: tensorflow-io-gcs-filesystem 0.32.0
# Adding tensorflow-io-gcs-filesystem 0.32.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for wrapt==1.14.1
# Best match: wrapt 1.14.1
# Adding wrapt 1.14.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for typing-extensions==4.5.0
# Best match: typing-extensions 4.5.0
# Adding typing-extensions 4.5.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for termcolor==2.2.0
# Best match: termcolor 2.2.0
# Adding termcolor 2.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for tensorflow-estimator==2.12.0
# Best match: tensorflow-estimator 2.12.0
# Adding tensorflow-estimator 2.12.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for tensorboard==2.12.1
# Best match: tensorboard 2.12.1
# Adding tensorboard 2.12.1 to easy-install.pth file
# Installing tensorboard script to /usr/local/bin
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for six==1.16.0
# Best match: six 1.16.0
# Adding six 1.16.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for setuptools==67.6.1
# Best match: setuptools 67.6.1
# Adding setuptools 67.6.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for protobuf==3.20.3
# Best match: protobuf 3.20.3
# Adding protobuf 3.20.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for packaging==23.0
# Best match: packaging 23.0
# Adding packaging 23.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for opt-einsum==3.3.0
# Best match: opt-einsum 3.3.0
# Adding opt-einsum 3.3.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for libclang==16.0.0
# Best match: libclang 16.0.0
# Adding libclang 16.0.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for jax==0.4.8
# Best match: jax 0.4.8
# Adding jax 0.4.8 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for h5py==3.8.0
# Best match: h5py 3.8.0
# Adding h5py 3.8.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for grpcio==1.53.0
# Best match: grpcio 1.53.0
# Adding grpcio 1.53.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for google-pasta==0.2.0
# Best match: google-pasta 0.2.0
# Adding google-pasta 0.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for gast==0.4.0
# Best match: gast 0.4.0
# Adding gast 0.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for flatbuffers==23.3.3
# Best match: flatbuffers 23.3.3
# Adding flatbuffers 23.3.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for astunparse==1.6.3
# Best match: astunparse 1.6.3
# Adding astunparse 1.6.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for absl-py==1.4.0
# Best match: absl-py 1.4.0
# Adding absl-py 1.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for importlib-resources==5.12.0
# Best match: importlib-resources 5.12.0
# Adding importlib-resources 5.12.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for python-dateutil==2.8.2
# Best match: python-dateutil 2.8.2
# Adding python-dateutil 2.8.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for pyparsing==3.0.9
# Best match: pyparsing 3.0.9
# Adding pyparsing 3.0.9 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for Pillow==8.4.0
# Best match: Pillow 8.4.0
# Adding Pillow 8.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for kiwisolver==1.4.4
# Best match: kiwisolver 1.4.4
# Adding kiwisolver 1.4.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for fonttools==4.39.3
# Best match: fonttools 4.39.3
# Adding fonttools 4.39.3 to easy-install.pth file
# Installing fonttools script to /usr/local/bin
# Installing pyftmerge script to /usr/local/bin
# Installing pyftsubset script to /usr/local/bin
# Installing ttx script to /usr/local/bin
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for cycler==0.11.0
# Best match: cycler 0.11.0
# Adding cycler 0.11.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for contourpy==1.0.7
# Best match: contourpy 1.0.7
# Adding contourpy 1.0.7 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for wheel==0.40.0
# Best match: wheel 0.40.0
# Adding wheel 0.40.0 to easy-install.pth file
# Installing wheel script to /usr/local/bin
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for Werkzeug==2.2.3
# Best match: Werkzeug 2.2.3
# Adding Werkzeug 2.2.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for tensorboard-plugin-wit==1.8.1
# Best match: tensorboard-plugin-wit 1.8.1
# Adding tensorboard-plugin-wit 1.8.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for tensorboard-data-server==0.7.0
# Best match: tensorboard-data-server 0.7.0
# Adding tensorboard-data-server 0.7.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for requests==2.27.1
# Best match: requests 2.27.1
# Adding requests 2.27.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for Markdown==3.4.3
# Best match: Markdown 3.4.3
# Adding Markdown 3.4.3 to easy-install.pth file
# Installing markdown_py script to /usr/local/bin
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for google-auth-oauthlib==1.0.0
# Best match: google-auth-oauthlib 1.0.0
# Adding google-auth-oauthlib 1.0.0 to easy-install.pth file
# Installing google-oauthlib-tool script to /usr/local/bin
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for google-auth==2.17.2
# Best match: google-auth 2.17.2
# Adding google-auth 2.17.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for scipy==1.10.1
# Best match: scipy 1.10.1
# Adding scipy 1.10.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for ml-dtypes==0.0.4
# Best match: ml-dtypes 0.0.4
# Adding ml-dtypes 0.0.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for zipp==3.15.0
# Best match: zipp 3.15.0
# Adding zipp 3.15.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for MarkupSafe==2.1.2
# Best match: MarkupSafe 2.1.2
# Adding MarkupSafe 2.1.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for idna==3.4
# Best match: idna 3.4
# Adding idna 3.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for charset-normalizer==2.0.12
# Best match: charset-normalizer 2.0.12
# Adding charset-normalizer 2.0.12 to easy-install.pth file
# Installing normalizer script to /usr/local/bin
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for certifi==2022.12.7
# Best match: certifi 2022.12.7
# Adding certifi 2022.12.7 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for urllib3==1.26.15
# Best match: urllib3 1.26.15
# Adding urllib3 1.26.15 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for importlib-metadata==6.3.0
# Best match: importlib-metadata 6.3.0
# Adding importlib-metadata 6.3.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for requests-oauthlib==1.3.1
# Best match: requests-oauthlib 1.3.1
# Adding requests-oauthlib 1.3.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for rsa==4.9
# Best match: rsa 4.9
# Adding rsa 4.9 to easy-install.pth file
# Installing pyrsa-decrypt script to /usr/local/bin
# Installing pyrsa-encrypt script to /usr/local/bin
# Installing pyrsa-keygen script to /usr/local/bin
# Installing pyrsa-priv2pub script to /usr/local/bin
# Installing pyrsa-sign script to /usr/local/bin
# Installing pyrsa-verify script to /usr/local/bin
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for pyasn1-modules==0.2.8
# Best match: pyasn1-modules 0.2.8
# Adding pyasn1-modules 0.2.8 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for cachetools==5.3.0
# Best match: cachetools 5.3.0
# Adding cachetools 5.3.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for oauthlib==3.2.2
# Best match: oauthlib 3.2.2
# Adding oauthlib 3.2.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for pyasn1==0.4.8
# Best match: pyasn1 0.4.8
# Adding pyasn1 0.4.8 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Finished processing dependencies for Rouse==0.1

# %%
from Rouse import *
from tensorflow.keras.datasets import cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()


print("found", len(x_train), "images!")
showSample(x_test, y_test, 16)
y_train, y_train_old = swapLabels(y_train, 0.6)

print("Labeling accuracy at start:", getLabelingAccuracy(y_train, y_train_old))
#showSample(changes, 16)

accuracyBefore = getValAccuracy(x_train, y_train, x_test, y_test, q = 0.7)
print(f"Validation accuracy before dataset modification: {accuracyBefore[0]}% with a loss of {accuracyBefore[1]}")
model, (x_train, y_train, y_train_old), metadata = trainEpochs((x_train, y_train, y_train_old), (x_test, y_test), 1, verbose = 1, augmentationForModification=10)
displayGraph(metadata)
accuracyAfter = getValAccuracy(x_train, y_train, x_test, y_test, q = 0.4)
print(f"Validation accuracy after dataset modification: {accuracyAfter[0]}% with a loss of {accuracyAfter[1]}")

#accuracyBefore = getValAccuracy(x_train, y_train, x_test, y_test)
#print(f"Validation accuracy before dataset modification: {accuracyBefore[0]}% with a loss of {accuracyBefore[1]}")
#model1, (x_train, y_train, y_train_old), metadata1 = trainEpochs((x_train, y_train, y_train_old), (x_test, y_test), MAIN_EPOCHS, verbose = 1, mode="delete")
#accuracyAfter = getValAccuracy(x_train, y_train, x_test, y_test)
#print(f"Validation accuracy after dataset modification: {accuracyAfter[0]}% with a loss of {accuracyAfter[1]}")

#displayGraph(metadata1)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 4s 0us/step
# found 50000 images!
# /usr/local/lib/python3.9/dist-packages/matplotlib/text.py:1279: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# (50000, 1)
# Labeling accuracy at start: 40.0
# Q:  0.7
# Epoch 1/120
# 391/391 [==============================] - 55s 82ms/step - loss: 2.8117 - accuracy: 0.1525 - val_loss: 2.6691 - val_accuracy: 0.3301 - lr: 0.0100
# Epoch 2/120
# 391/391 [==============================] - 30s 76ms/step - loss: 2.7634 - accuracy: 0.1831 - val_loss: 2.5681 - val_accuracy: 0.3825 - lr: 0.0100
# Epoch 3/120
# 391/391 [==============================] - 30s 76ms/step - loss: 2.7252 - accuracy: 0.1977 - val_loss: 2.4987 - val_accuracy: 0.3853 - lr: 0.0100
# Epoch 4/120
# 391/391 [==============================] - 30s 76ms/step - loss: 2.6875 - accuracy: 0.2101 - val_loss: 2.4098 - val_accuracy: 0.4460 - lr: 0.0100
# Epoch 5/120
# 391/391 [==============================] - 30s 76ms/step - loss: 2.6527 - accuracy: 0.2183 - val_loss: 2.3443 - val_accuracy: 0.4580 - lr: 0.0100
# Epoch 6/120
# 391/391 [==============================] - 30s 76ms/step - loss: 2.6182 - accuracy: 0.2305 - val_loss: 2.2961 - val_accuracy: 0.4821 - lr: 0.0100
# Epoch 7/120
# 391/391 [==============================] - 30s 76ms/step - loss: 2.5852 - accuracy: 0.2368 - val_loss: 2.2817 - val_accuracy: 0.4756 - lr: 0.0100
# Epoch 8/120
# 391/391 [==============================] - 30s 76ms/step - loss: 2.5539 - accuracy: 0.2441 - val_loss: 2.2277 - val_accuracy: 0.5029 - lr: 0.0100
# Epoch 9/120
# 391/391 [==============================] - 30s 76ms/step - loss: 2.5238 - accuracy: 0.2506 - val_loss: 2.1836 - val_accuracy: 0.5251 - lr: 0.0100
# Epoch 10/120
# 391/391 [==============================] - 30s 77ms/step - loss: 2.4933 - accuracy: 0.2575 - val_loss: 2.1150 - val_accuracy: 0.5357 - lr: 0.0100
# Epoch 11/120
# 391/391 [==============================] - 30s 77ms/step - loss: 2.4645 - accuracy: 0.2642 - val_loss: 2.0819 - val_accuracy: 0.5445 - lr: 0.0100
# Epoch 12/120
# 391/391 [==============================] - 30s 76ms/step - loss: 2.4349 - accuracy: 0.2700 - val_loss: 2.0987 - val_accuracy: 0.5078 - lr: 0.0100
# Epoch 13/120
# 391/391 [==============================] - 30s 76ms/step - loss: 2.4081 - accuracy: 0.2749 - val_loss: 2.0640 - val_accuracy: 0.5239 - lr: 0.0100
# Epoch 14/120
# 391/391 [==============================] - 30s 76ms/step - loss: 2.3804 - accuracy: 0.2798 - val_loss: 2.0975 - val_accuracy: 0.4682 - lr: 0.0100
# Epoch 15/120
# 391/391 [==============================] - 30s 76ms/step - loss: 2.3533 - accuracy: 0.2850 - val_loss: 1.9875 - val_accuracy: 0.5402 - lr: 0.0100
# Epoch 16/120
# 391/391 [==============================] - 30s 76ms/step - loss: 2.3292 - accuracy: 0.2872 - val_loss: 1.9063 - val_accuracy: 0.5893 - lr: 0.0100
# Epoch 17/120
# 391/391 [==============================] - 30s 76ms/step - loss: 2.3044 - accuracy: 0.2905 - val_loss: 1.9753 - val_accuracy: 0.5131 - lr: 0.0100
# Epoch 18/120
# 391/391 [==============================] - 30s 76ms/step - loss: 2.2794 - accuracy: 0.2951 - val_loss: 1.8811 - val_accuracy: 0.5874 - lr: 0.0100
# Epoch 19/120
# 391/391 [==============================] - 30s 76ms/step - loss: 2.2553 - accuracy: 0.2976 - val_loss: 1.7821 - val_accuracy: 0.6401 - lr: 0.0100
# Epoch 20/120
# 391/391 [==============================] - 30s 76ms/step - loss: 2.2320 - accuracy: 0.3017 - val_loss: 1.8676 - val_accuracy: 0.5538 - lr: 0.0100
# Epoch 21/120
# 391/391 [==============================] - 30s 76ms/step - loss: 2.2100 - accuracy: 0.3037 - val_loss: 1.7758 - val_accuracy: 0.6140 - lr: 0.0100
# Epoch 22/120
# 391/391 [==============================] - 30s 76ms/step - loss: 2.1878 - accuracy: 0.3073 - val_loss: 1.8286 - val_accuracy: 0.5554 - lr: 0.0100
# Epoch 23/120
# 391/391 [==============================] - 30s 76ms/step - loss: 2.1660 - accuracy: 0.3102 - val_loss: 1.6949 - val_accuracy: 0.6423 - lr: 0.0100
# Epoch 24/120
# 391/391 [==============================] - 30s 76ms/step - loss: 2.1443 - accuracy: 0.3121 - val_loss: 1.6592 - val_accuracy: 0.6595 - lr: 0.0100
# Epoch 25/120
# 391/391 [==============================] - 30s 76ms/step - loss: 2.1244 - accuracy: 0.3136 - val_loss: 1.6632 - val_accuracy: 0.6479 - lr: 0.0100
# Epoch 26/120
# 391/391 [==============================] - 30s 76ms/step - loss: 2.1036 - accuracy: 0.3162 - val_loss: 1.6139 - val_accuracy: 0.6686 - lr: 0.0100
# Epoch 27/120
# 391/391 [==============================] - 30s 76ms/step - loss: 2.0815 - accuracy: 0.3195 - val_loss: 1.5858 - val_accuracy: 0.6729 - lr: 0.0100
# Epoch 28/120
# 391/391 [==============================] - 30s 76ms/step - loss: 2.0620 - accuracy: 0.3225 - val_loss: 1.6018 - val_accuracy: 0.6470 - lr: 0.0100
# Epoch 29/120
# 391/391 [==============================] - 30s 76ms/step - loss: 2.0419 - accuracy: 0.3248 - val_loss: 1.5666 - val_accuracy: 0.6619 - lr: 0.0100
# Epoch 30/120
# 391/391 [==============================] - 30s 76ms/step - loss: 2.0237 - accuracy: 0.3251 - val_loss: 1.5238 - val_accuracy: 0.6817 - lr: 0.0100
# Epoch 31/120
# 391/391 [==============================] - 30s 76ms/step - loss: 2.0014 - accuracy: 0.3311 - val_loss: 1.5806 - val_accuracy: 0.6245 - lr: 0.0100
# Epoch 32/120
# 391/391 [==============================] - 30s 76ms/step - loss: 1.9852 - accuracy: 0.3298 - val_loss: 1.5761 - val_accuracy: 0.6186 - lr: 0.0100
# Epoch 33/120
# 391/391 [==============================] - 30s 76ms/step - loss: 1.9655 - accuracy: 0.3344 - val_loss: 1.5220 - val_accuracy: 0.6457 - lr: 0.0100
# Epoch 34/120
# 391/391 [==============================] - 30s 76ms/step - loss: 1.9485 - accuracy: 0.3349 - val_loss: 1.4563 - val_accuracy: 0.6784 - lr: 0.0100
# Epoch 35/120
# 391/391 [==============================] - 30s 76ms/step - loss: 1.9306 - accuracy: 0.3354 - val_loss: 1.3992 - val_accuracy: 0.7132 - lr: 0.0100
# Epoch 36/120
# 391/391 [==============================] - 30s 76ms/step - loss: 1.9109 - accuracy: 0.3406 - val_loss: 1.4050 - val_accuracy: 0.6973 - lr: 0.0100
# Epoch 37/120
# 391/391 [==============================] - 30s 76ms/step - loss: 1.8960 - accuracy: 0.3402 - val_loss: 1.5177 - val_accuracy: 0.5961 - lr: 0.0100
# Epoch 38/120
# 391/391 [==============================] - 30s 76ms/step - loss: 1.8773 - accuracy: 0.3453 - val_loss: 1.5869 - val_accuracy: 0.5388 - lr: 0.0100
# Epoch 39/120
# 391/391 [==============================] - 30s 76ms/step - loss: 1.8616 - accuracy: 0.3454 - val_loss: 1.3857 - val_accuracy: 0.6831 - lr: 0.0100
# Epoch 40/120
# 1563/1563 [==============================] - 10s 6ms/step
# 391/391 [==============================] - 42s 109ms/step - loss: 1.8456 - accuracy: 0.3475 - val_loss: 1.4482 - val_accuracy: 0.6149 - lr: 0.0100 - pruning_ratio: 0.1000 - num_examples_pruned: 5000.0000
# Epoch 41/120
# 391/391 [==============================] - 28s 71ms/step - loss: 1.7619 - accuracy: 0.4017 - val_loss: 1.2457 - val_accuracy: 0.7723 - lr: 1.0000e-03
# Epoch 42/120
# 391/391 [==============================] - 27s 69ms/step - loss: 1.7475 - accuracy: 0.4119 - val_loss: 1.2433 - val_accuracy: 0.7737 - lr: 1.0000e-03
# Epoch 43/120
# 391/391 [==============================] - 27s 69ms/step - loss: 1.7434 - accuracy: 0.4137 - val_loss: 1.2363 - val_accuracy: 0.7774 - lr: 1.0000e-03
# Epoch 44/120
# 391/391 [==============================] - 27s 69ms/step - loss: 1.7389 - accuracy: 0.4172 - val_loss: 1.2385 - val_accuracy: 0.7714 - lr: 1.0000e-03
# Epoch 45/120
# 391/391 [==============================] - 27s 69ms/step - loss: 1.7356 - accuracy: 0.4170 - val_loss: 1.2381 - val_accuracy: 0.7725 - lr: 1.0000e-03
# Epoch 46/120
# 391/391 [==============================] - 27s 69ms/step - loss: 1.7304 - accuracy: 0.4210 - val_loss: 1.2358 - val_accuracy: 0.7724 - lr: 1.0000e-03
# Epoch 47/120
# 391/391 [==============================] - 27s 69ms/step - loss: 1.7273 - accuracy: 0.4228 - val_loss: 1.2416 - val_accuracy: 0.7671 - lr: 1.0000e-03
# Epoch 48/120
# 391/391 [==============================] - 27s 69ms/step - loss: 1.7256 - accuracy: 0.4225 - val_loss: 1.2390 - val_accuracy: 0.7675 - lr: 1.0000e-03
# Epoch 49/120
# 391/391 [==============================] - 27s 69ms/step - loss: 1.7215 - accuracy: 0.4251 - val_loss: 1.2414 - val_accuracy: 0.7655 - lr: 1.0000e-03
# Epoch 50/120
# 1407/1407 [==============================] - 9s 6ms/step
# 391/391 [==============================] - 38s 97ms/step - loss: 1.7187 - accuracy: 0.4268 - val_loss: 1.2453 - val_accuracy: 0.7609 - lr: 1.0000e-03 - pruning_ratio: 0.1000 - num_examples_pruned: 4500.0000
# Epoch 51/120
# 391/391 [==============================] - 25s 65ms/step - loss: 1.6476 - accuracy: 0.4754 - val_loss: 1.2301 - val_accuracy: 0.7714 - lr: 1.0000e-03
# Epoch 52/120
# 391/391 [==============================] - 25s 63ms/step - loss: 1.6447 - accuracy: 0.4759 - val_loss: 1.2387 - val_accuracy: 0.7643 - lr: 1.0000e-03
# Epoch 53/120
# 391/391 [==============================] - 25s 63ms/step - loss: 1.6419 - accuracy: 0.4773 - val_loss: 1.2449 - val_accuracy: 0.7584 - lr: 1.0000e-03
# Epoch 54/120
# 391/391 [==============================] - 25s 63ms/step - loss: 1.6391 - accuracy: 0.4771 - val_loss: 1.2350 - val_accuracy: 0.7656 - lr: 1.0000e-03
# Epoch 55/120
# 391/391 [==============================] - 25s 63ms/step - loss: 1.6367 - accuracy: 0.4793 - val_loss: 1.2351 - val_accuracy: 0.7648 - lr: 1.0000e-03
# Epoch 56/120
# 391/391 [==============================] - 25s 63ms/step - loss: 1.6329 - accuracy: 0.4812 - val_loss: 1.2363 - val_accuracy: 0.7590 - lr: 1.0000e-03
# Epoch 57/120
# 391/391 [==============================] - 25s 63ms/step - loss: 1.6293 - accuracy: 0.4839 - val_loss: 1.2431 - val_accuracy: 0.7562 - lr: 1.0000e-03
# Epoch 58/120
# 391/391 [==============================] - 25s 63ms/step - loss: 1.6291 - accuracy: 0.4825 - val_loss: 1.2448 - val_accuracy: 0.7524 - lr: 1.0000e-03
# Epoch 59/120
# 391/391 [==============================] - 25s 63ms/step - loss: 1.6271 - accuracy: 0.4825 - val_loss: 1.2407 - val_accuracy: 0.7510 - lr: 1.0000e-03
# Epoch 60/120
# 1266/1266 [==============================] - 8s 6ms/step
# 391/391 [==============================] - 34s 87ms/step - loss: 1.6242 - accuracy: 0.4849 - val_loss: 1.2345 - val_accuracy: 0.7581 - lr: 1.0000e-03 - pruning_ratio: 0.1000 - num_examples_pruned: 4050.0000
# Epoch 61/120
# 391/391 [==============================] - 23s 60ms/step - loss: 1.5445 - accuracy: 0.5404 - val_loss: 1.2250 - val_accuracy: 0.7628 - lr: 1.0000e-03
# Epoch 62/120
# 391/391 [==============================] - 23s 58ms/step - loss: 1.5417 - accuracy: 0.5411 - val_loss: 1.2370 - val_accuracy: 0.7539 - lr: 1.0000e-03
# Epoch 63/120
# 391/391 [==============================] - 22s 57ms/step - loss: 1.5381 - accuracy: 0.5429 - val_loss: 1.2380 - val_accuracy: 0.7515 - lr: 1.0000e-03
# Epoch 64/120
# 391/391 [==============================] - 23s 57ms/step - loss: 1.5355 - accuracy: 0.5434 - val_loss: 1.2345 - val_accuracy: 0.7532 - lr: 1.0000e-03
# Epoch 65/120
# 391/391 [==============================] - 23s 58ms/step - loss: 1.5328 - accuracy: 0.5451 - val_loss: 1.2257 - val_accuracy: 0.7610 - lr: 1.0000e-03
# Epoch 66/120
# 391/391 [==============================] - 23s 58ms/step - loss: 1.5327 - accuracy: 0.5446 - val_loss: 1.2269 - val_accuracy: 0.7558 - lr: 1.0000e-03
# Epoch 67/120
# 391/391 [==============================] - 23s 58ms/step - loss: 1.5272 - accuracy: 0.5479 - val_loss: 1.2284 - val_accuracy: 0.7575 - lr: 1.0000e-03
# Epoch 68/120
# 391/391 [==============================] - 23s 58ms/step - loss: 1.5235 - accuracy: 0.5498 - val_loss: 1.2344 - val_accuracy: 0.7511 - lr: 1.0000e-03
# Epoch 69/120
# 391/391 [==============================] - 22s 57ms/step - loss: 1.5205 - accuracy: 0.5523 - val_loss: 1.2287 - val_accuracy: 0.7547 - lr: 1.0000e-03
# Epoch 70/120
# 1140/1140 [==============================] - 7s 6ms/step
# 391/391 [==============================] - 31s 80ms/step - loss: 1.5188 - accuracy: 0.5517 - val_loss: 1.2391 - val_accuracy: 0.7474 - lr: 1.0000e-03 - pruning_ratio: 0.1000 - num_examples_pruned: 3645.0000
# Epoch 71/120
# 391/391 [==============================] - 21s 54ms/step - loss: 1.4284 - accuracy: 0.6160 - val_loss: 1.2461 - val_accuracy: 0.7387 - lr: 1.0000e-03
# Epoch 72/120
# 391/391 [==============================] - 21s 52ms/step - loss: 1.4301 - accuracy: 0.6137 - val_loss: 1.2346 - val_accuracy: 0.7465 - lr: 1.0000e-03
# Epoch 73/120
# 391/391 [==============================] - 21s 53ms/step - loss: 1.4227 - accuracy: 0.6175 - val_loss: 1.2389 - val_accuracy: 0.7421 - lr: 1.0000e-03
# Epoch 74/120
# 391/391 [==============================] - 21s 53ms/step - loss: 1.4227 - accuracy: 0.6170 - val_loss: 1.2393 - val_accuracy: 0.7404 - lr: 1.0000e-03
# Epoch 75/120
# 391/391 [==============================] - 21s 52ms/step - loss: 1.4192 - accuracy: 0.6176 - val_loss: 1.2443 - val_accuracy: 0.7380 - lr: 1.0000e-03
# Epoch 76/120
# 391/391 [==============================] - 21s 54ms/step - loss: 1.4156 - accuracy: 0.6211 - val_loss: 1.2363 - val_accuracy: 0.7417 - lr: 1.0000e-03
# Epoch 77/120
# 391/391 [==============================] - 21s 52ms/step - loss: 1.4145 - accuracy: 0.6195 - val_loss: 1.2427 - val_accuracy: 0.7356 - lr: 1.0000e-03
# Epoch 78/120
# 391/391 [==============================] - 21s 52ms/step - loss: 1.4092 - accuracy: 0.6231 - val_loss: 1.2560 - val_accuracy: 0.7271 - lr: 1.0000e-03
# Epoch 79/120
# 391/391 [==============================] - 21s 52ms/step - loss: 1.4070 - accuracy: 0.6241 - val_loss: 1.2336 - val_accuracy: 0.7400 - lr: 1.0000e-03
# Epoch 80/120
# 1026/1026 [==============================] - 6s 6ms/step
# 391/391 [==============================] - 28s 72ms/step - loss: 1.4054 - accuracy: 0.6265 - val_loss: 1.2365 - val_accuracy: 0.7392 - lr: 1.0000e-03 - pruning_ratio: 0.1000 - num_examples_pruned: 3280.0000
# Epoch 81/120
# 391/391 [==============================] - 20s 50ms/step - loss: 1.2942 - accuracy: 0.7050 - val_loss: 1.2172 - val_accuracy: 0.7533 - lr: 1.0000e-04
# Epoch 82/120
# 391/391 [==============================] - 19s 48ms/step - loss: 1.2902 - accuracy: 0.7072 - val_loss: 1.2190 - val_accuracy: 0.7544 - lr: 1.0000e-04
# Epoch 83/120
# 391/391 [==============================] - 19s 48ms/step - loss: 1.2903 - accuracy: 0.7088 - val_loss: 1.2172 - val_accuracy: 0.7539 - lr: 1.0000e-04
# Epoch 84/120
# 391/391 [==============================] - 19s 48ms/step - loss: 1.2879 - accuracy: 0.7105 - val_loss: 1.2179 - val_accuracy: 0.7551 - lr: 1.0000e-04
# Epoch 85/120
# 391/391 [==============================] - 19s 48ms/step - loss: 1.2857 - accuracy: 0.7123 - val_loss: 1.2176 - val_accuracy: 0.7532 - lr: 1.0000e-04
# Epoch 86/120
# 391/391 [==============================] - 19s 48ms/step - loss: 1.2867 - accuracy: 0.7114 - val_loss: 1.2169 - val_accuracy: 0.7546 - lr: 1.0000e-04
# Epoch 87/120
# 391/391 [==============================] - 19s 48ms/step - loss: 1.2875 - accuracy: 0.7096 - val_loss: 1.2160 - val_accuracy: 0.7544 - lr: 1.0000e-04
# Epoch 88/120
# 391/391 [==============================] - 19s 48ms/step - loss: 1.2829 - accuracy: 0.7134 - val_loss: 1.2154 - val_accuracy: 0.7562 - lr: 1.0000e-04
# Epoch 89/120
# 391/391 [==============================] - 19s 48ms/step - loss: 1.2846 - accuracy: 0.7129 - val_loss: 1.2149 - val_accuracy: 0.7569 - lr: 1.0000e-04
# Epoch 90/120
# 923/923 [==============================] - 6s 6ms/step
# 391/391 [==============================] - 26s 66ms/step - loss: 1.2852 - accuracy: 0.7110 - val_loss: 1.2187 - val_accuracy: 0.7526 - lr: 1.0000e-04 - pruning_ratio: 0.1000 - num_examples_pruned: 2952.0000
# Epoch 91/120
# 391/391 [==============================] - 18s 46ms/step - loss: 1.1746 - accuracy: 0.7904 - val_loss: 1.2180 - val_accuracy: 0.7554 - lr: 1.0000e-04
# Epoch 92/120
# 391/391 [==============================] - 17s 44ms/step - loss: 1.1785 - accuracy: 0.7879 - val_loss: 1.2152 - val_accuracy: 0.7571 - lr: 1.0000e-04
# Epoch 93/120
# 391/391 [==============================] - 17s 44ms/step - loss: 1.1761 - accuracy: 0.7905 - val_loss: 1.2164 - val_accuracy: 0.7569 - lr: 1.0000e-04
# Epoch 94/120
# 391/391 [==============================] - 17s 44ms/step - loss: 1.1751 - accuracy: 0.7893 - val_loss: 1.2171 - val_accuracy: 0.7556 - lr: 1.0000e-04
# Epoch 95/120
# 391/391 [==============================] - 17s 44ms/step - loss: 1.1725 - accuracy: 0.7937 - val_loss: 1.2183 - val_accuracy: 0.7532 - lr: 1.0000e-04
# Epoch 96/120
# 391/391 [==============================] - 17s 44ms/step - loss: 1.1730 - accuracy: 0.7926 - val_loss: 1.2172 - val_accuracy: 0.7537 - lr: 1.0000e-04
# Epoch 97/120
# 391/391 [==============================] - 17s 44ms/step - loss: 1.1729 - accuracy: 0.7938 - val_loss: 1.2167 - val_accuracy: 0.7559 - lr: 1.0000e-04
# Epoch 98/120
# 391/391 [==============================] - 17s 44ms/step - loss: 1.1715 - accuracy: 0.7938 - val_loss: 1.2166 - val_accuracy: 0.7546 - lr: 1.0000e-04
# Epoch 99/120
# 391/391 [==============================] - 17s 44ms/step - loss: 1.1707 - accuracy: 0.7939 - val_loss: 1.2173 - val_accuracy: 0.7545 - lr: 1.0000e-04
# Epoch 100/120
# 831/831 [==============================] - 5s 6ms/step
# 391/391 [==============================] - 23s 60ms/step - loss: 1.1703 - accuracy: 0.7944 - val_loss: 1.2159 - val_accuracy: 0.7546 - lr: 1.0000e-04 - pruning_ratio: 0.1000 - num_examples_pruned: 2657.0000
# Epoch 101/120
# 391/391 [==============================] - 17s 42ms/step - loss: 1.0637 - accuracy: 0.8732 - val_loss: 1.2156 - val_accuracy: 0.7562 - lr: 1.0000e-04
# Epoch 102/120
# 391/391 [==============================] - 16s 40ms/step - loss: 1.0651 - accuracy: 0.8712 - val_loss: 1.2138 - val_accuracy: 0.7576 - lr: 1.0000e-04
# Epoch 103/120
# 391/391 [==============================] - 16s 40ms/step - loss: 1.0615 - accuracy: 0.8737 - val_loss: 1.2123 - val_accuracy: 0.7585 - lr: 1.0000e-04
# Epoch 104/120
# 391/391 [==============================] - 16s 41ms/step - loss: 1.0612 - accuracy: 0.8751 - val_loss: 1.2134 - val_accuracy: 0.7554 - lr: 1.0000e-04
# Epoch 105/120
# 391/391 [==============================] - 16s 41ms/step - loss: 1.0588 - accuracy: 0.8767 - val_loss: 1.2120 - val_accuracy: 0.7574 - lr: 1.0000e-04
# Epoch 106/120
# 391/391 [==============================] - 16s 41ms/step - loss: 1.0614 - accuracy: 0.8738 - val_loss: 1.2120 - val_accuracy: 0.7576 - lr: 1.0000e-04
# Epoch 107/120
# 391/391 [==============================] - 16s 40ms/step - loss: 1.0570 - accuracy: 0.8778 - val_loss: 1.2111 - val_accuracy: 0.7582 - lr: 1.0000e-04
# Epoch 108/120
# 391/391 [==============================] - 16s 40ms/step - loss: 1.0590 - accuracy: 0.8765 - val_loss: 1.2115 - val_accuracy: 0.7569 - lr: 1.0000e-04
# Epoch 109/120
# 391/391 [==============================] - 16s 41ms/step - loss: 1.0580 - accuracy: 0.8769 - val_loss: 1.2127 - val_accuracy: 0.7559 - lr: 1.0000e-04
# Epoch 110/120
# 748/748 [==============================] - 5s 6ms/step
# 391/391 [==============================] - 22s 55ms/step - loss: 1.0588 - accuracy: 0.8764 - val_loss: 1.2153 - val_accuracy: 0.7530 - lr: 1.0000e-04 - pruning_ratio: 0.1000 - num_examples_pruned: 2391.0000
# Epoch 111/120
# 391/391 [==============================] - 15s 38ms/step - loss: 0.9819 - accuracy: 0.9359 - val_loss: 1.2093 - val_accuracy: 0.7600 - lr: 1.0000e-04
# Epoch 112/120
# 391/391 [==============================] - 15s 37ms/step - loss: 0.9807 - accuracy: 0.9370 - val_loss: 1.2085 - val_accuracy: 0.7596 - lr: 1.0000e-04
# Epoch 113/120
# 391/391 [==============================] - 15s 37ms/step - loss: 0.9801 - accuracy: 0.9355 - val_loss: 1.2084 - val_accuracy: 0.7603 - lr: 1.0000e-04
# Epoch 114/120
# 391/391 [==============================] - 15s 37ms/step - loss: 0.9805 - accuracy: 0.9353 - val_loss: 1.2068 - val_accuracy: 0.7597 - lr: 1.0000e-04
# Epoch 115/120
# 391/391 [==============================] - 15s 37ms/step - loss: 0.9756 - accuracy: 0.9395 - val_loss: 1.2062 - val_accuracy: 0.7607 - lr: 1.0000e-04
# Epoch 116/120
# 391/391 [==============================] - 15s 38ms/step - loss: 0.9780 - accuracy: 0.9364 - val_loss: 1.2057 - val_accuracy: 0.7608 - lr: 1.0000e-04
# Epoch 117/120
# 391/391 [==============================] - 15s 37ms/step - loss: 0.9785 - accuracy: 0.9360 - val_loss: 1.2050 - val_accuracy: 0.7593 - lr: 1.0000e-04
# Epoch 118/120
# 391/391 [==============================] - 15s 37ms/step - loss: 0.9742 - accuracy: 0.9397 - val_loss: 1.2066 - val_accuracy: 0.7601 - lr: 1.0000e-04
# Epoch 119/120
# 391/391 [==============================] - 15s 37ms/step - loss: 0.9752 - accuracy: 0.9383 - val_loss: 1.2046 - val_accuracy: 0.7609 - lr: 1.0000e-04
# Epoch 120/120
# 673/673 [==============================] - 4s 6ms/step
# 391/391 [==============================] - 20s 51ms/step - loss: 0.9763 - accuracy: 0.9384 - val_loss: 1.2050 - val_accuracy: 0.7616 - lr: 1.0000e-04 - pruning_ratio: 0.1000 - num_examples_pruned: 2152.0000
# Validation accuracy before dataset modification: 76.16000175476074% with a loss of 1.2050124406814575
# Q:  0.4
# Epoch 1/41
# 391/391 [==============================] - 32s 49ms/step - loss: 3.1761 - accuracy: 0.1535 - val_loss: 3.0114 - val_accuracy: 0.2955 - lr: 0.0100
# Epoch 2/41
# 391/391 [==============================] - 17s 45ms/step - loss: 3.1306 - accuracy: 0.1816 - val_loss: 2.9167 - val_accuracy: 0.3655 - lr: 0.0100
# Epoch 3/41
# 391/391 [==============================] - 18s 45ms/step - loss: 3.0948 - accuracy: 0.1932 - val_loss: 2.8651 - val_accuracy: 0.3709 - lr: 0.0100
# Epoch 4/41
# 391/391 [==============================] - 17s 44ms/step - loss: 3.0602 - accuracy: 0.2070 - val_loss: 2.8560 - val_accuracy: 0.3833 - lr: 0.0100
# Epoch 5/41
# 391/391 [==============================] - 17s 44ms/step - loss: 3.0299 - accuracy: 0.2135 - val_loss: 2.7615 - val_accuracy: 0.4463 - lr: 0.0100
# Epoch 6/41
# 391/391 [==============================] - 17s 44ms/step - loss: 2.9992 - accuracy: 0.2199 - val_loss: 2.6969 - val_accuracy: 0.4561 - lr: 0.0100
# Epoch 7/41
# 391/391 [==============================] - 18s 46ms/step - loss: 2.9694 - accuracy: 0.2254 - val_loss: 2.7060 - val_accuracy: 0.4198 - lr: 0.0100
# Epoch 8/41
# 391/391 [==============================] - 17s 44ms/step - loss: 2.9394 - accuracy: 0.2328 - val_loss: 2.6636 - val_accuracy: 0.4138 - lr: 0.0100
# Epoch 9/41
# 391/391 [==============================] - 17s 44ms/step - loss: 2.9124 - accuracy: 0.2358 - val_loss: 2.5858 - val_accuracy: 0.4719 - lr: 0.0100
# Epoch 10/41
# 391/391 [==============================] - 17s 44ms/step - loss: 2.8837 - accuracy: 0.2417 - val_loss: 2.5896 - val_accuracy: 0.4907 - lr: 0.0100
# Epoch 11/41
# 391/391 [==============================] - 18s 45ms/step - loss: 2.8541 - accuracy: 0.2497 - val_loss: 2.5324 - val_accuracy: 0.4851 - lr: 0.0100
# Epoch 12/41
# 391/391 [==============================] - 18s 45ms/step - loss: 2.8279 - accuracy: 0.2566 - val_loss: 2.4836 - val_accuracy: 0.4962 - lr: 0.0100
# Epoch 13/41
# 391/391 [==============================] - 17s 45ms/step - loss: 2.7994 - accuracy: 0.2602 - val_loss: 2.4549 - val_accuracy: 0.4869 - lr: 0.0100
# Epoch 14/41
# 391/391 [==============================] - 18s 45ms/step - loss: 2.7751 - accuracy: 0.2636 - val_loss: 2.4060 - val_accuracy: 0.5230 - lr: 0.0100
# Epoch 15/41
# 391/391 [==============================] - 17s 44ms/step - loss: 2.7487 - accuracy: 0.2666 - val_loss: 2.4623 - val_accuracy: 0.4546 - lr: 0.0100
# Epoch 16/41
# 391/391 [==============================] - 18s 45ms/step - loss: 2.7219 - accuracy: 0.2716 - val_loss: 2.4110 - val_accuracy: 0.4759 - lr: 0.0100
# Epoch 17/41
# 391/391 [==============================] - 17s 44ms/step - loss: 2.6969 - accuracy: 0.2747 - val_loss: 2.3272 - val_accuracy: 0.5017 - lr: 0.0100
# Epoch 18/41
# 391/391 [==============================] - 17s 44ms/step - loss: 2.6736 - accuracy: 0.2805 - val_loss: 2.2897 - val_accuracy: 0.5342 - lr: 0.0100
# Epoch 19/41
# 391/391 [==============================] - 17s 45ms/step - loss: 2.6494 - accuracy: 0.2858 - val_loss: 2.2819 - val_accuracy: 0.5513 - lr: 0.0100
# Epoch 20/41
# 391/391 [==============================] - 18s 45ms/step - loss: 2.6239 - accuracy: 0.2886 - val_loss: 2.2498 - val_accuracy: 0.5008 - lr: 0.0100
# Epoch 21/41
# 391/391 [==============================] - 18s 45ms/step - loss: 2.5990 - accuracy: 0.2943 - val_loss: 2.2318 - val_accuracy: 0.5003 - lr: 0.0100
# Epoch 22/41
# 391/391 [==============================] - 18s 45ms/step - loss: 2.5771 - accuracy: 0.2950 - val_loss: 2.1353 - val_accuracy: 0.5824 - lr: 0.0100
# Epoch 23/41
# 391/391 [==============================] - 17s 45ms/step - loss: 2.5520 - accuracy: 0.2974 - val_loss: 2.1716 - val_accuracy: 0.5697 - lr: 0.0100
# Epoch 24/41
# 391/391 [==============================] - 18s 45ms/step - loss: 2.5280 - accuracy: 0.3022 - val_loss: 2.1604 - val_accuracy: 0.5336 - lr: 0.0100
# Epoch 25/41
# 391/391 [==============================] - 18s 45ms/step - loss: 2.5065 - accuracy: 0.3038 - val_loss: 2.1931 - val_accuracy: 0.5084 - lr: 0.0100
# Epoch 26/41
# 391/391 [==============================] - 18s 45ms/step - loss: 2.4875 - accuracy: 0.3054 - val_loss: 2.1720 - val_accuracy: 0.4844 - lr: 0.0100
# Epoch 27/41
# 391/391 [==============================] - 18s 45ms/step - loss: 2.4625 - accuracy: 0.3106 - val_loss: 2.1605 - val_accuracy: 0.4874 - lr: 0.0100
# Epoch 28/41
# 391/391 [==============================] - 18s 45ms/step - loss: 2.4398 - accuracy: 0.3139 - val_loss: 2.0365 - val_accuracy: 0.5881 - lr: 0.0100
# Epoch 29/41
# 391/391 [==============================] - 17s 44ms/step - loss: 2.4182 - accuracy: 0.3171 - val_loss: 2.0334 - val_accuracy: 0.5635 - lr: 0.0100
# Epoch 30/41
# 391/391 [==============================] - 17s 44ms/step - loss: 2.3969 - accuracy: 0.3196 - val_loss: 1.9777 - val_accuracy: 0.5827 - lr: 0.0100
# Epoch 31/41
# 391/391 [==============================] - 18s 45ms/step - loss: 2.3766 - accuracy: 0.3252 - val_loss: 2.0201 - val_accuracy: 0.5465 - lr: 0.0100
# Epoch 32/41
# 391/391 [==============================] - 18s 45ms/step - loss: 2.3518 - accuracy: 0.3295 - val_loss: 1.9782 - val_accuracy: 0.5650 - lr: 0.0100
# Epoch 33/41
# 391/391 [==============================] - 18s 45ms/step - loss: 2.3347 - accuracy: 0.3297 - val_loss: 1.9716 - val_accuracy: 0.5614 - lr: 0.0100
# Epoch 34/41
# 391/391 [==============================] - 18s 45ms/step - loss: 2.3125 - accuracy: 0.3321 - val_loss: 1.9680 - val_accuracy: 0.5563 - lr: 0.0100
# Epoch 35/41
# 391/391 [==============================] - 18s 45ms/step - loss: 2.2924 - accuracy: 0.3368 - val_loss: 1.9866 - val_accuracy: 0.4999 - lr: 0.0100
# Epoch 36/41
# 391/391 [==============================] - 18s 46ms/step - loss: 2.2662 - accuracy: 0.3456 - val_loss: 1.9018 - val_accuracy: 0.5484 - lr: 0.0100
# Epoch 37/41
# 391/391 [==============================] - 18s 45ms/step - loss: 2.2471 - accuracy: 0.3467 - val_loss: 1.8830 - val_accuracy: 0.5632 - lr: 0.0100
# Epoch 38/41
# 391/391 [==============================] - 17s 45ms/step - loss: 2.2266 - accuracy: 0.3498 - val_loss: 1.8894 - val_accuracy: 0.5610 - lr: 0.0100
# Epoch 39/41
# 391/391 [==============================] - 17s 45ms/step - loss: 2.2070 - accuracy: 0.3517 - val_loss: 1.8825 - val_accuracy: 0.5465 - lr: 0.0100
# Epoch 40/41
# 782/782 [==============================] - 6s 6ms/step
# 391/391 [==============================] - 25s 63ms/step - loss: 2.1875 - accuracy: 0.3552 - val_loss: 1.9834 - val_accuracy: 0.4771 - lr: 0.0100 - pruning_ratio: 0.1000 - num_examples_pruned: 2500.0000
# Epoch 41/41
# 391/391 [==============================] - 17s 43ms/step - loss: 2.0253 - accuracy: 0.4379 - val_loss: 1.7421 - val_accuracy: 0.6389 - lr: 1.0000e-03
# 782/782 [==============================] - 5s 6ms/step
# 782/782 [==============================] - 5s 6ms/step
# 782/782 [==============================] - 5s 7ms/step
# 782/782 [==============================] - 5s 6ms/step
# 782/782 [==============================] - 5s 6ms/step
# 782/782 [==============================] - 5s 6ms/step
# 782/782 [==============================] - 5s 6ms/step
# 782/782 [==============================] - 5s 6ms/step
# 782/782 [==============================] - 5s 6ms/step
# 782/782 [==============================] - 5s 6ms/step
# 0
# 1250
# 2500
# 3750
# 5000
# 6250
# 7500
# 8750
# 10000
# 11250
# 12500
# 13750
# 15000
# 16250
# 17500
# 18750
# 20000
# 21250
# 22500
# 23750
# ======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# | Elapsed: 0:15:28 | Epoch 1 |  First half epoch | Model training progress: ========================================= 41/41 | Validation accuracy: 63.88% | Validation loss: 1.742 | Dataset modification progress: ==================== 25000/25000 | Dataset half accuracy before half epoch: 39.81% | Dataset half accuracy after half epoch: 53.22% | Correct relabelling: 14.12% | Incorrect relabelling:  0.71% | Neutral relabelling:  0.87% | Total dataset accuracy: 46.71% |
# ======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# Q:  0.4
# Epoch 1/41
# 391/391 [==============================] - 31s 48ms/step - loss: 3.1786 - accuracy: 0.1498 - val_loss: 3.0432 - val_accuracy: 0.2656 - lr: 0.0100
# Epoch 2/41
# 391/391 [==============================] - 17s 44ms/step - loss: 3.1360 - accuracy: 0.1808 - val_loss: 2.9415 - val_accuracy: 0.3570 - lr: 0.0100
# Epoch 3/41
# 391/391 [==============================] - 18s 45ms/step - loss: 3.0992 - accuracy: 0.1920 - val_loss: 2.8659 - val_accuracy: 0.4016 - lr: 0.0100
# Epoch 4/41
# 391/391 [==============================] - 18s 45ms/step - loss: 3.0657 - accuracy: 0.2017 - val_loss: 2.8138 - val_accuracy: 0.4077 - lr: 0.0100
# Epoch 5/41
# 391/391 [==============================] - 18s 46ms/step - loss: 3.0336 - accuracy: 0.2113 - val_loss: 2.7612 - val_accuracy: 0.4167 - lr: 0.0100
# Epoch 6/41
# 391/391 [==============================] - 18s 45ms/step - loss: 3.0031 - accuracy: 0.2166 - val_loss: 2.7172 - val_accuracy: 0.4556 - lr: 0.0100
# Epoch 7/41
# 391/391 [==============================] - 18s 46ms/step - loss: 2.9716 - accuracy: 0.2260 - val_loss: 2.6749 - val_accuracy: 0.4691 - lr: 0.0100
# Epoch 8/41
# 391/391 [==============================] - 18s 45ms/step - loss: 2.9445 - accuracy: 0.2327 - val_loss: 2.6255 - val_accuracy: 0.4655 - lr: 0.0100
# Epoch 9/41
# 391/391 [==============================] - 18s 45ms/step - loss: 2.9142 - accuracy: 0.2362 - val_loss: 2.5896 - val_accuracy: 0.4716 - lr: 0.0100
# Epoch 10/41
# 391/391 [==============================] - 18s 45ms/step - loss: 2.8862 - accuracy: 0.2412 - val_loss: 2.5468 - val_accuracy: 0.4980 - lr: 0.0100
# Epoch 11/41
# 391/391 [==============================] - 18s 45ms/step - loss: 2.8606 - accuracy: 0.2437 - val_loss: 2.5154 - val_accuracy: 0.4821 - lr: 0.0100
# Epoch 12/41
# 391/391 [==============================] - 18s 45ms/step - loss: 2.8319 - accuracy: 0.2518 - val_loss: 2.4631 - val_accuracy: 0.5541 - lr: 0.0100
# Epoch 13/41
# 391/391 [==============================] - 17s 44ms/step - loss: 2.8064 - accuracy: 0.2576 - val_loss: 2.4506 - val_accuracy: 0.5176 - lr: 0.0100
# Epoch 14/41
# 391/391 [==============================] - 17s 44ms/step - loss: 2.7774 - accuracy: 0.2635 - val_loss: 2.4048 - val_accuracy: 0.5391 - lr: 0.0100
# Epoch 15/41
# 391/391 [==============================] - 18s 45ms/step - loss: 2.7531 - accuracy: 0.2663 - val_loss: 2.3840 - val_accuracy: 0.4820 - lr: 0.0100
# Epoch 16/41
# 391/391 [==============================] - 18s 45ms/step - loss: 2.7268 - accuracy: 0.2700 - val_loss: 2.3264 - val_accuracy: 0.5585 - lr: 0.0100
# Epoch 17/41
# 391/391 [==============================] - 18s 45ms/step - loss: 2.7021 - accuracy: 0.2739 - val_loss: 2.2950 - val_accuracy: 0.5324 - lr: 0.0100
# Epoch 18/41
# 391/391 [==============================] - 18s 45ms/step - loss: 2.6780 - accuracy: 0.2780 - val_loss: 2.3322 - val_accuracy: 0.5336 - lr: 0.0100
# Epoch 19/41
# 391/391 [==============================] - 17s 44ms/step - loss: 2.6534 - accuracy: 0.2814 - val_loss: 2.2884 - val_accuracy: 0.5522 - lr: 0.0100
# Epoch 20/41
# 391/391 [==============================] - 18s 45ms/step - loss: 2.6295 - accuracy: 0.2841 - val_loss: 2.3459 - val_accuracy: 0.4409 - lr: 0.0100
# Epoch 21/41
# 391/391 [==============================] - 17s 45ms/step - loss: 2.6069 - accuracy: 0.2850 - val_loss: 2.2008 - val_accuracy: 0.5660 - lr: 0.0100
# Epoch 22/41
# 391/391 [==============================] - 17s 45ms/step - loss: 2.5832 - accuracy: 0.2909 - val_loss: 2.1438 - val_accuracy: 0.6125 - lr: 0.0100
# Epoch 23/41
# 391/391 [==============================] - 17s 44ms/step - loss: 2.5593 - accuracy: 0.2939 - val_loss: 2.1916 - val_accuracy: 0.5236 - lr: 0.0100
# Epoch 24/41
# 391/391 [==============================] - 18s 45ms/step - loss: 2.5343 - accuracy: 0.3012 - val_loss: 2.0944 - val_accuracy: 0.5978 - lr: 0.0100
# Epoch 25/41
# 391/391 [==============================] - 17s 44ms/step - loss: 2.5145 - accuracy: 0.3003 - val_loss: 2.1260 - val_accuracy: 0.5689 - lr: 0.0100
# Epoch 26/41
# 391/391 [==============================] - 17s 44ms/step - loss: 2.4906 - accuracy: 0.3042 - val_loss: 2.1388 - val_accuracy: 0.5339 - lr: 0.0100
# Epoch 27/41
# 391/391 [==============================] - 17s 44ms/step - loss: 2.4693 - accuracy: 0.3078 - val_loss: 2.0834 - val_accuracy: 0.5548 - lr: 0.0100
# Epoch 28/41
# 391/391 [==============================] - 18s 45ms/step - loss: 2.4479 - accuracy: 0.3068 - val_loss: 2.0899 - val_accuracy: 0.5785 - lr: 0.0100
# Epoch 29/41
# 391/391 [==============================] - 18s 45ms/step - loss: 2.4257 - accuracy: 0.3105 - val_loss: 2.0896 - val_accuracy: 0.5211 - lr: 0.0100
# Epoch 30/41
# 391/391 [==============================] - 17s 44ms/step - loss: 2.4021 - accuracy: 0.3195 - val_loss: 2.0575 - val_accuracy: 0.5369 - lr: 0.0100
# Epoch 31/41
# 391/391 [==============================] - 17s 45ms/step - loss: 2.3809 - accuracy: 0.3189 - val_loss: 2.0030 - val_accuracy: 0.5661 - lr: 0.0100
# Epoch 32/41
# 391/391 [==============================] - 17s 44ms/step - loss: 2.3611 - accuracy: 0.3216 - val_loss: 2.0242 - val_accuracy: 0.5383 - lr: 0.0100
# Epoch 33/41
# 391/391 [==============================] - 17s 44ms/step - loss: 2.3377 - accuracy: 0.3240 - val_loss: 2.1311 - val_accuracy: 0.4378 - lr: 0.0100
# Epoch 34/41
# 391/391 [==============================] - 17s 45ms/step - loss: 2.3173 - accuracy: 0.3285 - val_loss: 2.0273 - val_accuracy: 0.4893 - lr: 0.0100
# Epoch 35/41
# 391/391 [==============================] - 17s 44ms/step - loss: 2.2956 - accuracy: 0.3326 - val_loss: 2.0092 - val_accuracy: 0.5034 - lr: 0.0100
# Epoch 36/41
# 391/391 [==============================] - 18s 45ms/step - loss: 2.2765 - accuracy: 0.3358 - val_loss: 1.9372 - val_accuracy: 0.5357 - lr: 0.0100
# Epoch 37/41
# 391/391 [==============================] - 17s 44ms/step - loss: 2.2534 - accuracy: 0.3417 - val_loss: 1.9683 - val_accuracy: 0.5207 - lr: 0.0100
# Epoch 38/41
# 391/391 [==============================] - 17s 44ms/step - loss: 2.2322 - accuracy: 0.3459 - val_loss: 2.0089 - val_accuracy: 0.4549 - lr: 0.0100
# Epoch 39/41
# 391/391 [==============================] - 18s 45ms/step - loss: 2.2112 - accuracy: 0.3470 - val_loss: 1.9014 - val_accuracy: 0.5312 - lr: 0.0100
# Epoch 40/41
# 782/782 [==============================] - 6s 6ms/step
# 391/391 [==============================] - 24s 61ms/step - loss: 2.1876 - accuracy: 0.3555 - val_loss: 1.9109 - val_accuracy: 0.5179 - lr: 0.0100 - pruning_ratio: 0.1000 - num_examples_pruned: 2500.0000
# Epoch 41/41
# 391/391 [==============================] - 16s 41ms/step - loss: 2.0274 - accuracy: 0.4371 - val_loss: 1.7598 - val_accuracy: 0.6235 - lr: 1.0000e-03
# 782/782 [==============================] - 5s 6ms/step
# 782/782 [==============================] - 5s 6ms/step
# 782/782 [==============================] - 5s 6ms/step
# 782/782 [==============================] - 5s 6ms/step
# 782/782 [==============================] - 5s 6ms/step
# 782/782 [==============================] - 5s 6ms/step
# 782/782 [==============================] - 5s 6ms/step
# 782/782 [==============================] - 5s 6ms/step
# 782/782 [==============================] - 5s 6ms/step
# 782/782 [==============================] - 5s 6ms/step
# 0
# 1250
# 2500
# 3750
# 5000
# 6250
# 7500
# 8750
# 10000
# 11250
# 12500
# 13750
# 15000
# 16250
# 17500
# 18750
# 20000
# 21250
# 22500
# 23750
# ======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# | Elapsed: 0:15:19 | Epoch 1 | Second half epoch | Model training progress: ========================================= 41/41 | Validation accuracy: 62.33% | Validation loss: 1.760 | Dataset modification progress: ==================== 25000/25000 | Dataset half accuracy before half epoch: 40.19% | Dataset half accuracy after half epoch: 52.60% | Correct relabelling: 13.06% | Incorrect relabelling:  0.65% | Neutral relabelling:  0.93% | Total dataset accuracy: 52.91% |
# ======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# Q:  0.4
# Epoch 1/120
# 391/391 [==============================] - 44s 80ms/step - loss: 3.0913 - accuracy: 0.2373 - val_loss: 2.8271 - val_accuracy: 0.3950 - lr: 0.0100
# Epoch 2/120
# 391/391 [==============================] - 30s 77ms/step - loss: 2.9852 - accuracy: 0.3062 - val_loss: 2.6577 - val_accuracy: 0.4701 - lr: 0.0100
# Epoch 3/120
# 391/391 [==============================] - 30s 77ms/step - loss: 2.9091 - accuracy: 0.3437 - val_loss: 2.5898 - val_accuracy: 0.5139 - lr: 0.0100
# Epoch 4/120
# 391/391 [==============================] - 30s 76ms/step - loss: 2.8455 - accuracy: 0.3698 - val_loss: 2.5111 - val_accuracy: 0.5484 - lr: 0.0100
# Epoch 5/120
# 391/391 [==============================] - 30s 77ms/step - loss: 2.7901 - accuracy: 0.3913 - val_loss: 2.5602 - val_accuracy: 0.4944 - lr: 0.0100
# Epoch 6/120
# 391/391 [==============================] - 30s 77ms/step - loss: 2.7412 - accuracy: 0.4060 - val_loss: 2.4157 - val_accuracy: 0.5515 - lr: 0.0100
# Epoch 7/120
# 391/391 [==============================] - 30s 76ms/step - loss: 2.6984 - accuracy: 0.4183 - val_loss: 2.3121 - val_accuracy: 0.6100 - lr: 0.0100
# Epoch 8/120
# 391/391 [==============================] - 30s 77ms/step - loss: 2.6612 - accuracy: 0.4250 - val_loss: 2.4772 - val_accuracy: 0.4843 - lr: 0.0100
# Epoch 9/120
# 391/391 [==============================] - 30s 78ms/step - loss: 2.6282 - accuracy: 0.4309 - val_loss: 2.2465 - val_accuracy: 0.6295 - lr: 0.0100
# Epoch 10/120
# 391/391 [==============================] - 30s 77ms/step - loss: 2.5940 - accuracy: 0.4398 - val_loss: 2.2168 - val_accuracy: 0.6311 - lr: 0.0100
# Epoch 11/120
# 391/391 [==============================] - 30s 76ms/step - loss: 2.5642 - accuracy: 0.4427 - val_loss: 2.1810 - val_accuracy: 0.6452 - lr: 0.0100
# Epoch 12/120
# 391/391 [==============================] - 30s 77ms/step - loss: 2.5347 - accuracy: 0.4463 - val_loss: 2.2153 - val_accuracy: 0.6155 - lr: 0.0100
# Epoch 13/120
# 391/391 [==============================] - 30s 77ms/step - loss: 2.5047 - accuracy: 0.4532 - val_loss: 2.2093 - val_accuracy: 0.5813 - lr: 0.0100
# Epoch 14/120
# 391/391 [==============================] - 30s 77ms/step - loss: 2.4784 - accuracy: 0.4537 - val_loss: 2.1095 - val_accuracy: 0.6394 - lr: 0.0100
# Epoch 15/120
# 391/391 [==============================] - 30s 77ms/step - loss: 2.4498 - accuracy: 0.4575 - val_loss: 2.0695 - val_accuracy: 0.6594 - lr: 0.0100
# Epoch 16/120
# 391/391 [==============================] - 30s 77ms/step - loss: 2.4228 - accuracy: 0.4614 - val_loss: 2.0671 - val_accuracy: 0.6403 - lr: 0.0100
# Epoch 17/120
# 391/391 [==============================] - 30s 77ms/step - loss: 2.4002 - accuracy: 0.4627 - val_loss: 2.0630 - val_accuracy: 0.6434 - lr: 0.0100
# Epoch 18/120
# 391/391 [==============================] - 30s 76ms/step - loss: 2.3720 - accuracy: 0.4669 - val_loss: 2.0515 - val_accuracy: 0.6396 - lr: 0.0100
# Epoch 19/120
# 391/391 [==============================] - 30s 77ms/step - loss: 2.3498 - accuracy: 0.4686 - val_loss: 1.9985 - val_accuracy: 0.6498 - lr: 0.0100
# Epoch 20/120
# 391/391 [==============================] - 30s 77ms/step - loss: 2.3247 - accuracy: 0.4719 - val_loss: 1.9058 - val_accuracy: 0.7018 - lr: 0.0100
# Epoch 21/120
# 391/391 [==============================] - 30s 76ms/step - loss: 2.2989 - accuracy: 0.4745 - val_loss: 1.9590 - val_accuracy: 0.6381 - lr: 0.0100
# Epoch 22/120
# 391/391 [==============================] - 30s 77ms/step - loss: 2.2737 - accuracy: 0.4793 - val_loss: 1.9064 - val_accuracy: 0.6720 - lr: 0.0100
# Epoch 23/120
# 391/391 [==============================] - 30s 77ms/step - loss: 2.2524 - accuracy: 0.4811 - val_loss: 1.8745 - val_accuracy: 0.6701 - lr: 0.0100
# Epoch 24/120
# 391/391 [==============================] - 30s 76ms/step - loss: 2.2305 - accuracy: 0.4819 - val_loss: 1.8792 - val_accuracy: 0.6741 - lr: 0.0100
# Epoch 25/120
# 391/391 [==============================] - 30s 76ms/step - loss: 2.2072 - accuracy: 0.4855 - val_loss: 1.8529 - val_accuracy: 0.6735 - lr: 0.0100
# Epoch 26/120
# 391/391 [==============================] - 30s 76ms/step - loss: 2.1836 - accuracy: 0.4885 - val_loss: 1.7702 - val_accuracy: 0.7135 - lr: 0.0100
# Epoch 27/120
# 391/391 [==============================] - 30s 76ms/step - loss: 2.1640 - accuracy: 0.4892 - val_loss: 1.8624 - val_accuracy: 0.6375 - lr: 0.0100
# Epoch 28/120
# 391/391 [==============================] - 30s 77ms/step - loss: 2.1406 - accuracy: 0.4930 - val_loss: 1.8040 - val_accuracy: 0.6646 - lr: 0.0100
# Epoch 29/120
# 391/391 [==============================] - 30s 77ms/step - loss: 2.1220 - accuracy: 0.4939 - val_loss: 1.7811 - val_accuracy: 0.6632 - lr: 0.0100
# Epoch 30/120
# 391/391 [==============================] - 30s 77ms/step - loss: 2.1002 - accuracy: 0.4966 - val_loss: 1.7558 - val_accuracy: 0.6700 - lr: 0.0100
# Epoch 31/120
# 391/391 [==============================] - 30s 77ms/step - loss: 2.0793 - accuracy: 0.4990 - val_loss: 1.6934 - val_accuracy: 0.7008 - lr: 0.0100
# Epoch 32/120
# 391/391 [==============================] - 30s 77ms/step - loss: 2.0573 - accuracy: 0.5008 - val_loss: 1.7621 - val_accuracy: 0.6573 - lr: 0.0100
# Epoch 33/120
# 391/391 [==============================] - 30s 77ms/step - loss: 2.0399 - accuracy: 0.5031 - val_loss: 1.7012 - val_accuracy: 0.6803 - lr: 0.0100
# Epoch 34/120
# 391/391 [==============================] - 30s 77ms/step - loss: 2.0188 - accuracy: 0.5059 - val_loss: 1.6975 - val_accuracy: 0.6743 - lr: 0.0100
# Epoch 35/120
# 391/391 [==============================] - 30s 78ms/step - loss: 1.9990 - accuracy: 0.5099 - val_loss: 1.7066 - val_accuracy: 0.6519 - lr: 0.0100
# Epoch 36/120
# 391/391 [==============================] - 30s 77ms/step - loss: 1.9785 - accuracy: 0.5119 - val_loss: 1.6422 - val_accuracy: 0.6913 - lr: 0.0100
# Epoch 37/120
# 391/391 [==============================] - 30s 77ms/step - loss: 1.9587 - accuracy: 0.5138 - val_loss: 1.6825 - val_accuracy: 0.6580 - lr: 0.0100
# Epoch 38/120
# 391/391 [==============================] - 30s 77ms/step - loss: 1.9395 - accuracy: 0.5168 - val_loss: 1.6803 - val_accuracy: 0.6454 - lr: 0.0100
# Epoch 39/120
# 391/391 [==============================] - 30s 77ms/step - loss: 1.9223 - accuracy: 0.5182 - val_loss: 1.6271 - val_accuracy: 0.6739 - lr: 0.0100
# Epoch 40/120
# 1563/1563 [==============================] - 10s 6ms/step
# 391/391 [==============================] - 42s 108ms/step - loss: 1.9042 - accuracy: 0.5177 - val_loss: 1.6538 - val_accuracy: 0.6605 - lr: 0.0100 - pruning_ratio: 0.1000 - num_examples_pruned: 5000.0000
# Epoch 41/120
# 391/391 [==============================] - 27s 70ms/step - loss: 1.7171 - accuracy: 0.6040 - val_loss: 1.5090 - val_accuracy: 0.7371 - lr: 1.0000e-03
# Epoch 42/120
# 391/391 [==============================] - 27s 70ms/step - loss: 1.6869 - accuracy: 0.6199 - val_loss: 1.5016 - val_accuracy: 0.7307 - lr: 1.0000e-03
# Epoch 43/120
# 391/391 [==============================] - 27s 70ms/step - loss: 1.6753 - accuracy: 0.6240 - val_loss: 1.5220 - val_accuracy: 0.7220 - lr: 1.0000e-03
# Epoch 44/120
# 391/391 [==============================] - 27s 70ms/step - loss: 1.6627 - accuracy: 0.6316 - val_loss: 1.5200 - val_accuracy: 0.7156 - lr: 1.0000e-03
# Epoch 45/120
# 391/391 [==============================] - 27s 70ms/step - loss: 1.6547 - accuracy: 0.6328 - val_loss: 1.5313 - val_accuracy: 0.7097 - lr: 1.0000e-03
# Epoch 46/120
# 391/391 [==============================] - 27s 70ms/step - loss: 1.6475 - accuracy: 0.6374 - val_loss: 1.5401 - val_accuracy: 0.7033 - lr: 1.0000e-03
# Epoch 47/120
# 391/391 [==============================] - 27s 70ms/step - loss: 1.6419 - accuracy: 0.6400 - val_loss: 1.5402 - val_accuracy: 0.7038 - lr: 1.0000e-03
# Epoch 48/120
# 391/391 [==============================] - 27s 70ms/step - loss: 1.6315 - accuracy: 0.6452 - val_loss: 1.5281 - val_accuracy: 0.7065 - lr: 1.0000e-03
# Epoch 49/120
# 251/391 [==================>...........] - ETA: 9s - loss: 1.6284 - accuracy: 0.6461
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-47a1881946e5> in <cell line: 18>()
#      16 model, (x_train, y_train, y_train_old), metadata = trainEpochs((x_train, y_train, y_train_old), (x_test, y_test), 1, verbose = 1, augmentationForModification=10)
#      17 displayGraph(metadata)
# ---> 18 accuracyAfter = getValAccuracy(x_train, y_train, x_test, y_test, q = 0.4)
#      19 print(f"Validation accuracy after dataset modification: {accuracyAfter[0]}% with a loss of {accuracyAfter[1]}")
#      20
#
# /content/Rouse/dataClean.py in getValAccuracy(x_train, y_train, x_test, y_test, q)
#     630 def getValAccuracy(x_train, y_train, x_test, y_test, q = 0.4):
#     631   train_imagesEncoded, val_imagesEncoded = convertToUseful(x_train, y_train, x_test, y_test)
# --> 632   model = trainModel(train_imagesEncoded, val_imagesEncoded, epochcount=120, loadingBar=False, fast=False, q = q)
#     633   val_accuracy, val_loss = getAccuracy(val_imagesEncoded, model)
#     634   return val_accuracy, val_loss
#
# /content/Rouse/dataClean.py in trainModel(ds, val_ds, epochcount, loadingBar, fast, q)
#     380     callbacks.append(CustomCallback())
#     381
# --> 382   model.fit(train_generator, validation_data=val_ds, epochs=(TRAIN_EPOCHS if not epochcount else epochcount), callbacks=callbacks, verbose=1)#, validation_data=val_ds)
#     383   model.load_weights(checkpoint_path)
#     384   return model
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1683                         ):
#    1684                             callbacks.on_train_batch_begin(step)
# -> 1685                             tmp_logs = self.train_function(iterator)
#    1686                             if data_handler.should_sync:
#    1687                                 context.async_wait()
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     892
#     893       with OptionalXlaContext(self._jit_compile):
# --> 894         result = self._call(*args, **kwds)
#     895
#     896       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     924       # In this case we have created variables on the first call, so we run the
#     925       # defunned version which is guaranteed to never create variables.
# --> 926       return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     927     elif self._variable_creation_fn is not None:
#     928       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in __call__(self, *args, **kwargs)
#     141       (concrete_function,
#     142        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143     return concrete_function._call_flat(
#     144         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     145
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1755         and executing_eagerly):
#    1756       # No tape is watching; skip to running the function.
# -> 1757       return self._build_call_outputs(self._inference_function.call(
#    1758           ctx, args, cancellation_manager=cancellation_manager))
#    1759     forward_backward = self._select_forward_and_backward_functions(
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     379       with _InterpolateFunctionError(self):
#     380         if cancellation_manager is None:
# --> 381           outputs = execute.execute(
#     382               str(self.signature.name),
#     383               num_outputs=self._num_outputs,
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
print(metadata)
print(len(images))
correct, incorrect = getCorrectSample(images)
print(len(correct))
print(len(incorrect))
showSample(correct, 16)
showSample(incorrect, 16)

# %%
#metadata = {'val accuracy': [91.36666655540466, 93.7166690826416, 94.23333406448364, 94.81666684150696, 95.45000195503235, 96.31666541099548, 96.78333401679993, 96.14999890327454], 'val loss': [0.9319291114807129, 0.5999569892883301, 0.36166685819625854, 0.21822355687618256, 0.17234396934509277, 0.12887966632843018, 0.11454400420188904, 0.13207554817199707], 'dataset accuracy before': [50.59259259259259, 49.407407407407405, 66.4074074074074, 66.77407407407408, 91.40370370370371, 91.35185185185185, 95.64444444444445, 96.08148148148148], 'dataset accuracy after': [57.733333333333334, 75.44814814814815, 89.22592592592594, 93.52962962962962, 95.25925925925925, 96.46666666666667, 96.57777777777777, 96.87037037037037], 'dataset correct relabelling': [7.151851851851852, 26.185185185185183, 23.18148148148148, 27.48888888888889, 4.588888888888889, 5.774074074074074, 1.5962962962962963, 1.6481481481481481], 'dataset incorrect relabelling': [0.011111111111111112, 0.14444444444444443, 0.362962962962963, 0.7333333333333333, 0.7333333333333333, 0.6592592592592592, 0.662962962962963, 0.8592592592592593], 'total dataset accuracy': [53.57037037037037, 66.59074074074074, 78.0, 91.37777777777778, 93.30555555555556, 95.86296296296297, 96.32962962962964, 96.72407407407407]} # Remove me

# %%
displayGraph(metadata)

# %%
print(labels)

# %%
images = getImages()
images = random.sample(images, 10000)
print("found", len(images), "images!")
images, val_images = splitTrainVal(images, 0.1)
#showSample(images, 16)
#showSample(val_images, 16)
images, changes = swapLabels(images, 0.5)
print("Labeling accuracy at start:", getLabelingAccuracy(images))
#showSample(changes, 16)

model, images1, metadata = trainEpochs(copy.deepcopy(images), MAIN_EPOCHS, verbose = 1)

displayGraph(metadata)

model1, images1, metadata1 = trainEpochs(copy.deepcopy(images), MAIN_EPOCHS, verbose = 1, mode="delete")

displayGraph(metadata1)
print(metadatalist)

# %%
for metadata in metadatalist:
  displayGraph(metadata)
