# %%
# !git clone https://github.com/Yetiowner/Rouse
# !cd Rouse
# !python Rouse/setup.py install
# Out:
# Cloning into 'Rouse'...
# remote: Enumerating objects: 605, done.
# remote: Counting objects: 100% (76/76), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 605 (delta 25), reused 60 (delta 21), pack-reused 529
# Receiving objects: 100% (605/605), 187.17 MiB | 23.54 MiB/s, done.
# Resolving deltas: 100% (345/345), done.
# running install
# /usr/lib/python3.10/distutils/cmd.py:62: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/lib/python3.10/distutils/cmd.py:62: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# creating Rouse.egg-info
# writing Rouse.egg-info/PKG-INFO
# writing dependency_links to Rouse.egg-info/dependency_links.txt
# writing requirements to Rouse.egg-info/requires.txt
# writing top-level names to Rouse.egg-info/top_level.txt
# writing manifest file 'Rouse.egg-info/SOURCES.txt'
# reading manifest file 'Rouse.egg-info/SOURCES.txt'
# writing manifest file 'Rouse.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/Rouse
# copying Rouse/dataClean.py -> build/lib/Rouse
# copying Rouse/graphshow.py -> build/lib/Rouse
# copying Rouse/setup.py -> build/lib/Rouse
# copying Rouse/pytorchgraphshow.py -> build/lib/Rouse
# copying Rouse/GCE.py -> build/lib/Rouse
# copying Rouse/usage.py -> build/lib/Rouse
# copying Rouse/unpickleds.py -> build/lib/Rouse
# copying Rouse/__init__.py -> build/lib/Rouse
# copying Rouse/graphgen.py -> build/lib/Rouse
# copying Rouse/main.py -> build/lib/Rouse
# copying Rouse/modelResNet.py -> build/lib/Rouse
# copying Rouse/test.py -> build/lib/Rouse
# copying Rouse/pytorchgraphgen.py -> build/lib/Rouse
# copying Rouse/mnist ds.py -> build/lib/Rouse
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/Rouse
# copying build/lib/Rouse/dataClean.py -> build/bdist.linux-x86_64/egg/Rouse
# copying build/lib/Rouse/graphshow.py -> build/bdist.linux-x86_64/egg/Rouse
# copying build/lib/Rouse/setup.py -> build/bdist.linux-x86_64/egg/Rouse
# copying build/lib/Rouse/pytorchgraphshow.py -> build/bdist.linux-x86_64/egg/Rouse
# copying build/lib/Rouse/GCE.py -> build/bdist.linux-x86_64/egg/Rouse
# copying build/lib/Rouse/usage.py -> build/bdist.linux-x86_64/egg/Rouse
# copying build/lib/Rouse/unpickleds.py -> build/bdist.linux-x86_64/egg/Rouse
# copying build/lib/Rouse/__init__.py -> build/bdist.linux-x86_64/egg/Rouse
# copying build/lib/Rouse/graphgen.py -> build/bdist.linux-x86_64/egg/Rouse
# copying build/lib/Rouse/main.py -> build/bdist.linux-x86_64/egg/Rouse
# copying build/lib/Rouse/modelResNet.py -> build/bdist.linux-x86_64/egg/Rouse
# copying build/lib/Rouse/test.py -> build/bdist.linux-x86_64/egg/Rouse
# copying build/lib/Rouse/pytorchgraphgen.py -> build/bdist.linux-x86_64/egg/Rouse
# copying build/lib/Rouse/mnist ds.py -> build/bdist.linux-x86_64/egg/Rouse
# byte-compiling build/bdist.linux-x86_64/egg/Rouse/dataClean.py to dataClean.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/Rouse/graphshow.py to graphshow.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/Rouse/setup.py to setup.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/Rouse/pytorchgraphshow.py to pytorchgraphshow.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/Rouse/GCE.py to GCE.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/Rouse/usage.py to usage.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/Rouse/unpickleds.py to unpickleds.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/Rouse/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/Rouse/graphgen.py to graphgen.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/Rouse/main.py to main.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/Rouse/modelResNet.py to modelResNet.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/Rouse/test.py to test.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/Rouse/pytorchgraphgen.py to pytorchgraphgen.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/Rouse/mnist ds.py to mnist ds.cpython-310.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying Rouse.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying Rouse.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying Rouse.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying Rouse.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying Rouse.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating dist
# creating 'dist/Rouse-0.1-py3.10.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing Rouse-0.1-py3.10.egg
# Copying Rouse-0.1-py3.10.egg to /usr/local/lib/python3.10/dist-packages
# Adding Rouse 0.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/Rouse-0.1-py3.10.egg
# Processing dependencies for Rouse==0.1
# Searching for tensorflow==2.12.0
# Best match: tensorflow 2.12.0
# Adding tensorflow 2.12.0 to easy-install.pth file
# Installing estimator_ckpt_converter script to /usr/local/bin
# Installing import_pb_to_tensorboard script to /usr/local/bin
# Installing saved_model_cli script to /usr/local/bin
# Installing tensorboard script to /usr/local/bin
# Installing tf_upgrade_v2 script to /usr/local/bin
# Installing tflite_convert script to /usr/local/bin
# Installing toco script to /usr/local/bin
# Installing toco_from_protos script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for numpy==1.22.4
# Best match: numpy 1.22.4
# Adding numpy 1.22.4 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.10 script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for matplotlib==3.7.1
# Best match: matplotlib 3.7.1
# Adding matplotlib 3.7.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for opencv-python==4.7.0.72
# Best match: opencv-python 4.7.0.72
# Adding opencv-python 4.7.0.72 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for keras==2.12.0
# Best match: keras 2.12.0
# Adding keras 2.12.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for tensorflow-io-gcs-filesystem==0.32.0
# Best match: tensorflow-io-gcs-filesystem 0.32.0
# Adding tensorflow-io-gcs-filesystem 0.32.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for wrapt==1.14.1
# Best match: wrapt 1.14.1
# Adding wrapt 1.14.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for typing-extensions==4.5.0
# Best match: typing-extensions 4.5.0
# Adding typing-extensions 4.5.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for termcolor==2.3.0
# Best match: termcolor 2.3.0
# Adding termcolor 2.3.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for tensorflow-estimator==2.12.0
# Best match: tensorflow-estimator 2.12.0
# Adding tensorflow-estimator 2.12.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for tensorboard==2.12.2
# Best match: tensorboard 2.12.2
# Adding tensorboard 2.12.2 to easy-install.pth file
# Installing tensorboard script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for six==1.16.0
# Best match: six 1.16.0
# Adding six 1.16.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for setuptools==67.7.2
# Best match: setuptools 67.7.2
# Adding setuptools 67.7.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for protobuf==3.20.3
# Best match: protobuf 3.20.3
# Adding protobuf 3.20.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for packaging==23.1
# Best match: packaging 23.1
# Adding packaging 23.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for opt-einsum==3.3.0
# Best match: opt-einsum 3.3.0
# Adding opt-einsum 3.3.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for libclang==16.0.0
# Best match: libclang 16.0.0
# Adding libclang 16.0.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for jax==0.4.8
# Best match: jax 0.4.8
# Adding jax 0.4.8 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for h5py==3.8.0
# Best match: h5py 3.8.0
# Adding h5py 3.8.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for grpcio==1.54.0
# Best match: grpcio 1.54.0
# Adding grpcio 1.54.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for google-pasta==0.2.0
# Best match: google-pasta 0.2.0
# Adding google-pasta 0.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for gast==0.4.0
# Best match: gast 0.4.0
# Adding gast 0.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for flatbuffers==23.3.3
# Best match: flatbuffers 23.3.3
# Adding flatbuffers 23.3.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for astunparse==1.6.3
# Best match: astunparse 1.6.3
# Adding astunparse 1.6.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for absl-py==1.4.0
# Best match: absl-py 1.4.0
# Adding absl-py 1.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for python-dateutil==2.8.2
# Best match: python-dateutil 2.8.2
# Adding python-dateutil 2.8.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for pyparsing==3.0.9
# Best match: pyparsing 3.0.9
# Adding pyparsing 3.0.9 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for Pillow==8.4.0
# Best match: Pillow 8.4.0
# Adding Pillow 8.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for kiwisolver==1.4.4
# Best match: kiwisolver 1.4.4
# Adding kiwisolver 1.4.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for fonttools==4.39.3
# Best match: fonttools 4.39.3
# Adding fonttools 4.39.3 to easy-install.pth file
# Installing fonttools script to /usr/local/bin
# Installing pyftmerge script to /usr/local/bin
# Installing pyftsubset script to /usr/local/bin
# Installing ttx script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for cycler==0.11.0
# Best match: cycler 0.11.0
# Adding cycler 0.11.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for contourpy==1.0.7
# Best match: contourpy 1.0.7
# Adding contourpy 1.0.7 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for wheel==0.40.0
# Best match: wheel 0.40.0
# Adding wheel 0.40.0 to easy-install.pth file
# Installing wheel script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for Werkzeug==2.3.0
# Best match: Werkzeug 2.3.0
# Adding Werkzeug 2.3.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for tensorboard-plugin-wit==1.8.1
# Best match: tensorboard-plugin-wit 1.8.1
# Adding tensorboard-plugin-wit 1.8.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for tensorboard-data-server==0.7.0
# Best match: tensorboard-data-server 0.7.0
# Adding tensorboard-data-server 0.7.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for requests==2.27.1
# Best match: requests 2.27.1
# Adding requests 2.27.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for Markdown==3.4.3
# Best match: Markdown 3.4.3
# Adding Markdown 3.4.3 to easy-install.pth file
# Installing markdown_py script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for google-auth-oauthlib==1.0.0
# Best match: google-auth-oauthlib 1.0.0
# Adding google-auth-oauthlib 1.0.0 to easy-install.pth file
# Installing google-oauthlib-tool script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for google-auth==2.17.3
# Best match: google-auth 2.17.3
# Adding google-auth 2.17.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for scipy==1.10.1
# Best match: scipy 1.10.1
# Adding scipy 1.10.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for ml-dtypes==0.1.0
# Best match: ml-dtypes 0.1.0
# Adding ml-dtypes 0.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for MarkupSafe==2.1.2
# Best match: MarkupSafe 2.1.2
# Adding MarkupSafe 2.1.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for idna==3.4
# Best match: idna 3.4
# Adding idna 3.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for charset-normalizer==2.0.12
# Best match: charset-normalizer 2.0.12
# Adding charset-normalizer 2.0.12 to easy-install.pth file
# Installing normalizer script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for certifi==2022.12.7
# Best match: certifi 2022.12.7
# Adding certifi 2022.12.7 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for urllib3==1.26.15
# Best match: urllib3 1.26.15
# Adding urllib3 1.26.15 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for requests-oauthlib==1.3.1
# Best match: requests-oauthlib 1.3.1
# Adding requests-oauthlib 1.3.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for rsa==4.9
# Best match: rsa 4.9
# Adding rsa 4.9 to easy-install.pth file
# Installing pyrsa-decrypt script to /usr/local/bin
# Installing pyrsa-encrypt script to /usr/local/bin
# Installing pyrsa-keygen script to /usr/local/bin
# Installing pyrsa-priv2pub script to /usr/local/bin
# Installing pyrsa-sign script to /usr/local/bin
# Installing pyrsa-verify script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for pyasn1-modules==0.3.0
# Best match: pyasn1-modules 0.3.0
# Adding pyasn1-modules 0.3.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for cachetools==5.3.0
# Best match: cachetools 5.3.0
# Adding cachetools 5.3.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for oauthlib==3.2.2
# Best match: oauthlib 3.2.2
# Adding oauthlib 3.2.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for pyasn1==0.5.0
# Best match: pyasn1 0.5.0
# Adding pyasn1 0.5.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Finished processing dependencies for Rouse==0.1

# %%
from Rouse import *
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from google.colab.patches import cv2_imshow

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
datagen = ImageDataGenerator(
      rotation_range=15, # rotate images randomly by 15 degrees
      width_shift_range=0.3, # shift images horizontally by 10% of total width
      height_shift_range=0.3, # shift images vertically by 10% of total height
      shear_range=0.2, # apply shear transformation with intensity of 10%
      zoom_range=0.2, # zoom images randomly by 10%
      horizontal_flip=True, # flip images horizontally
      fill_mode='reflect', # fill mode for padding, uses reflection
      brightness_range=(0.8, 1.2), # randomly adjust brightness between 0.9 and 1.1
  )

chosenimage = x_train[5128][..., ::-1]
cv2_imshow(chosenimage)
showAugmentedImages(chosenimage, 10, datagen)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 6s 0us/step
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F04845D7850>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F04156F6320>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F04156F78E0>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F04156F7730>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F04156F76A0>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F041573B2E0>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F041573B2E0>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F041573AB30>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F041573B490>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F041573B520>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F041573B460>

# %%
"""from Rouse import *
from tensorflow.keras.datasets import cifar10
import copy

(x_train, y_train), (x_test, y_test) = cifar10.load_data()


print("found", len(x_train), "images!")
showSample(x_test, y_test, 16)
y_train, y_train_old = swapLabels(y_train, 0.8)
xtraincopy = copy.deepcopy(x_train)
ytraincopy = copy.deepcopy(y_train)
ytrainoldcopy = copy.deepcopy(y_train_old)

print("Labeling accuracy at start:", getLabelingAccuracy(y_train, y_train_old))
#showSample(changes, 16)

accuracyBefore = getValAccuracy(x_train, y_train, x_test, y_test, q = 0.7)
print(f"Validation accuracy before dataset modification: {accuracyBefore[0]}% with a loss of {accuracyBefore[1]}")"""
"""model, (x_train, y_train, y_train_old), metadata = trainEpochs((x_train, y_train, y_train_old), (x_test, y_test), 1, verbose = 1, augmentationForModification=10, subEpochs = 50, subQValue = 0.7, monoepoch = False)
displayGraph(metadata)
accuracyAfter = getValAccuracy(x_train, y_train, x_test, y_test, q = 0.7)
print(f"Validation accuracy after dataset modification: {accuracyAfter[0]}% with a loss of {accuracyAfter[1]}")
"""
model, (x_train, y_train, y_train_old), metadata = trainEpochs((xtraincopy, ytraincopy, ytrainoldcopy), (x_test, y_test), 1, verbose = 1, augmentationForModification=10, subEpochs = 50, subQValue = 0.7, monoepoch = True, mu = 0.8)
displayGraph(metadata)
accuracyAfter = getValAccuracy(x_train, y_train, x_test, y_test, q = 0.7)
print(f"Validation accuracy after dataset modification: {accuracyAfter[0]}% with a loss of {accuracyAfter[1]}")

#accuracyBefore = getValAccuracy(x_train, y_train, x_test, y_test)
#print(f"Validation accuracy before dataset modification: {accuracyBefore[0]}% with a loss of {accuracyBefore[1]}")
#model1, (x_train, y_train, y_train_old), metadata1 = trainEpochs((x_train, y_train, y_train_old), (x_test, y_test), MAIN_EPOCHS, verbose = 1, mode="delete")
#accuracyAfter = getValAccuracy(x_train, y_train, x_test, y_test)
#print(f"Validation accuracy after dataset modification: {accuracyAfter[0]}% with a loss of {accuracyAfter[1]}")

#displayGraph(metadata1)
# Out:
# Epoch: 0
#  [================================================================>]  Step: 39ms | Tot: 51s931ms | Loss: 0.603 | Acc: 10.400% (5200/50000) 782/782
#  [================================================================>]  Step: 21ms | Tot: 7s92ms | Loss: 0.574 | Acc: 15.440% (1544/10000) 157/157
#
# Epoch: 1
#  [================================================================>]  Step: 35ms | Tot: 51s78ms | Loss: 0.597 | Acc: 11.390% (5695/50000) 782/782
#  [================================================================>]  Step: 14ms | Tot: 5s933ms | Loss: 0.533 | Acc: 25.270% (2527/10000) 157/157
#
# Epoch: 2
#  [================================================================>]  Step: 38ms | Tot: 51s966ms | Loss: 0.596 | Acc: 11.272% (5636/50000) 782/782
#  [================================================================>]  Step: 21ms | Tot: 7s209ms | Loss: 0.553 | Acc: 19.550% (1955/10000) 157/157
#
# Epoch: 3
#  [================================================================>]  Step: 40ms | Tot: 51s128ms | Loss: 0.594 | Acc: 11.630% (5815/50000) 782/782
#  [================================================================>]  Step: 26ms | Tot: 6s62ms | Loss: 0.517 | Acc: 28.530% (2853/10000) 157/157
#
# Epoch: 4
#  [================================================================>]  Step: 36ms | Tot: 53s549ms | Loss: 0.595 | Acc: 11.834% (5917/50000) 782/782
#  [================================================================>]  Step: 18ms | Tot: 7s246ms | Loss: 0.516 | Acc: 26.370% (2637/10000) 157/157
#
# Epoch: 5
#  [================================================================>]  Step: 55ms | Tot: 52s420ms | Loss: 0.594 | Acc: 11.992% (5996/50000) 782/782
#  [================================================================>]  Step: 25ms | Tot: 6s140ms | Loss: 0.514 | Acc: 29.570% (2957/10000) 157/157
#
# Epoch: 6
#  [================================================================>]  Step: 30ms | Tot: 52s632ms | Loss: 0.592 | Acc: 12.282% (6141/50000) 782/782
#  [================================================================>]  Step: 28ms | Tot: 6s983ms | Loss: 0.513 | Acc: 31.740% (3174/10000) 157/157
#
# Epoch: 7
#  [================================================================>]  Step: 39ms | Tot: 53s575ms | Loss: 0.592 | Acc: 12.580% (6290/50000) 782/782
#  [================================================================>]  Step: 28ms | Tot: 6s162ms | Loss: 0.505 | Acc: 33.080% (3308/10000) 157/157
#
# Epoch: 8
#  [================================================================>]  Step: 40ms | Tot: 52s384ms | Loss: 0.591 | Acc: 12.952% (6476/50000) 782/782
#  [================================================================>]  Step: 28ms | Tot: 7s189ms | Loss: 0.485 | Acc: 31.900% (3190/10000) 157/157
#
# Epoch: 9
#  [================================================================>]  Step: 45ms | Tot: 51s575ms | Loss: 0.590 | Acc: 12.902% (6451/50000) 782/782
#  [================================================================>]  Step: 29ms | Tot:
50000) 782/782
#  [================================================================>]  Step: 24ms | Tot: 7s752ms | Loss: 0.005 | Acc: 35.290% (3529/10000) 157/157
# foo
# <torch.utils.data.dataloader.DataLoader object at 0x7f033dc10340>
# torch.Size([10000, 10])
# bar
# 1
# 2
# <torch.utils.data.dataloader.DataLoader object at 0x7f033fcfa1d0>
# torch.Size([50000, 10])
# <torch.utils.data.dataloader.DataLoader object at 0x7f033fcfb580>
# torch.Size([50000, 10])
# <torch.utils.data.dataloader.DataLoader object at 0x7f033fcf91b0>
# torch.Size([50000, 10])
# <torch.utils.data.dataloader.DataLoader object at 0x7f033fcf91b0>
# torch.Size([50000, 10])
# <torch.utils.data.dataloader.DataLoader object at 0x7f033f739840>
# torch.Size([50000, 10])
# <torch.utils.data.dataloader.DataLoader object at 0x7f0341edd0f0>
# torch.Size([50000, 10])
# <torch.utils.data.dataloader.DataLoader object at 0x7f04157ef910>
# torch.Size([50000, 10])
# <torch.utils.data.dataloader.DataLoader object at 0x7f033f739840>
# torch.Size([50000, 10])
# <torch.utils.data.dataloader.DataLoader object at 0x7f033dc58a90>
# torch.Size([50000, 10])
# <torch.utils.data.dataloader.DataLoader object at 0x7f033dc6f940>
# torch.Size([50000, 10])
# 3
# 0
# 2500
# 5000
# 7500
# 10000
# 12500
# 15000
# 17500
# 20000
# 22500
# 25000
# 27500
# 30000
# 32500
# 35000
# 37500
# 40000
# 42500
# 45000
# 47500
# ===============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# | Elapsed: 1:03:35 | Epoch 1 |  First half epoch | Model training progress: ..................................................  0/50 | Validation accuracy: 35.29% | Validation loss: 2.110 | Dataset modification progress: ==================== 50000/50000 | Dataset half accuracy before half epoch: 20.00% | Dataset half accuracy after half epoch: 30.83% | Correct relabelling: 24.33% | Incorrect relabelling: 13.50% | Neutral relabelling: 48.93% | Total dataset accuracy: 30.83% |
# ===============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# Epoch: 0
#  [================================================================>]  Step: 44ms | Tot: 54s815ms | Loss: -0.039 | Acc: 63.302% (31651/50000) 782/782
#  [================================================================>]  Step: 26ms | Tot: 7s732ms | Loss: 0.481 | Acc: 27.390% (2739/10000) 157/157
#
# Epoch: 1
#  [================================================================>]  Step: 34ms | Tot: 56s896ms | Loss: -0.125 | Acc: 69.182% (34591/50000) 782/782
#  [================================================================>]  Step: 36ms | Tot: 6s593ms | Loss: 0.436 | Acc: 30.150% (3015/10000) 157/157
#
# Epoch: 2
#  [================================================================>]  Step: 54ms | Tot: 55s540ms | Loss: -0.159 | Acc: 71.568% (35784/50000) 782/782
#  [================================================================>]  Step: 32ms | Tot: 7s533ms | Loss: 0.432 | Acc: 30.750% (3075/10000) 157/157
#
# Epoch: 3
#  [================================================================>]  Step: 39ms | Tot: 55s406ms | Loss: -0.178 | Acc: 72.854% (36427/50000) 782/782
#  [================================================================>]  Step: 28ms | Tot:
50000) 782/782
#  [================================================================>]  Step: 23ms | Tot: 7s871ms | Loss: 0.029 | Acc: 34.280% (3428/10000) 157/157
#
# Epoch: 95
#  [================================================================>]  Step: 38ms | Tot: 56s136ms | Loss: -0.041 | Acc: 77.820% (38910/50000) 782/782
#  [================================================================>]  Step: 25ms | Tot: 7s752ms | Loss: 0.029 | Acc: 34.430% (3443/10000) 157/157
#
# Epoch: 96
#  [================================================================>]  Step: 38ms | Tot: 56s212ms | Loss: -0.041 | Acc: 78.060% (39030/50000) 782/782
#  [================================================================>]  Step: 30ms | Tot: 8s601ms | Loss: 0.029 | Acc: 34.540% (3454/10000) 157/157
#
# Epoch: 97
#  [================================================================>]  Step: 40ms | Tot: 56s375ms | Loss: -0.041 | Acc: 78.004% (39002/50000) 782/782
#  [================================================================>]  Step: 33ms | Tot: 7s768ms | Loss: 0.029 | Acc: 34.430% (3443/10000) 157/157
#
# Epoch: 98
#  [================================================================>]  Step: 44ms | Tot: 55s971ms | Loss: -0.041 | Acc: 77.864% (38932/50000) 782/782
#  [================================================================>]  Step: 24ms | Tot: 7s790ms | Loss: 0.029 | Acc: 34.290% (3429/10000) 157/157
#
# Epoch: 99
#  [================================================================>]  Step: 43ms | Tot: 56s887ms | Loss: -0.042 | Acc: 77.906% (38953/50000) 782/782
#  [================================================================>]  Step: 32ms | Tot: 6s903ms | Loss: 0.028 | Acc: 34.290% (3429/10000) 157/157
#
# Epoch: 100
#  [================================================================>]  Step: 45ms | Tot: 56s242ms | Loss: -0.042 | Acc: 77.818% (38909/50000) 782/782
#  [================================================================>]  Step: 21ms | Tot: 7s358ms | Loss: 0.028 | Acc: 34.440% (3444/10000) 157/157
#
# Epoch: 101
#  [================================================================>]  Step: 44ms | Tot: 56s340ms | Loss: -0.042 | Acc: 78.074% (39037/50000) 782/782
#  [================================================================>]  Step: 22ms | Tot: 7s772ms | Loss: 0.028 | Acc: 34.310% (3431/10000) 157/157
#
# Epoch: 102
#  [================================================================>]  Step: 39ms | Tot: 56s178ms | Loss: -0.042 | Acc: 77.802% (38901/50000) 782/782
#  [================================================================>]  Step: 20ms | Tot: 7s770ms | Loss: 0.028 | Acc: 34.220% (3422/10000) 157/157
#
# Epoch: 103
#  [================================================================>]  Step: 40ms | Tot: 56s4ms | Loss: -0.042 | Acc: 77.946% (38973/50000) 782/782
#  [================================================================>]  Step: 21ms | Tot: 7s857ms | Loss: 0.028 | Acc: 34.680% (3468/10000) 157/157
#
# Epoch: 104
#  [================================================================>]  Step: 39ms | Tot: 56s709ms | Loss: -0.042 | Acc: 77.924% (38962/50000) 782/782
#  [================================================================>]  Step: 16ms | Tot: 7s571ms | Loss: 0.028 | Acc: 34.450% (3445/10000) 157/157
#
# Epoch: 105
#  [================================================================>]  Step: 42ms | Tot: 55s762ms | Loss: -0.042 | Acc: 77.740% (38870/50000) 782/782
#  [================================================================>]  Step: 19ms | Tot: 7s763ms | Loss: 0.028 | Acc: 34.220% (3422/10000) 157/157
#
# Epoch: 106
#  [================================================================>]  Step: 42ms | Tot: 55s646ms | Loss: -0.042 | Acc: 77.884% (38942/50000) 782/782
#  [================================================================>]  Step: 26ms | Tot: 6s952ms | Loss: 0.027 | Acc: 34.480% (3448/10000) 157/157
#
# Epoch: 119
#  [================================================================>]  Step: 49ms | Tot: 56s126ms | Loss: -0.041 | Acc: 77.856% (38928/50000) 782/782
#  [================================================================>]  Step: 21ms | Tot: 8s228ms | Loss: 0.027 | Acc: 34.480% (3448/10000) 157/157
# foo
# <torch.utils.data.dataloader.DataLoader object at 0x7f033fcf8ac0>
# torch.Size([10000, 10])
# bar
# Validation accuracy after dataset modification: 34.47999954223633% with a loss of 2.1126551628112793

# %%
from Rouse import *
from tensorflow.keras.datasets import cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()


print("found", len(x_train), "images!")
showSample(x_test, y_test, 16)
y_train, y_train_old = swapLabels(y_train, 0.4)

print("Labeling accuracy at start:", getLabelingAccuracy(y_train, y_train_old))
#showSample(changes, 16)

#accuracyBefore = getValAccuracy(x_train, y_train, x_test, y_test, q = 0.7)
#print(f"Validation accuracy before dataset modification: {accuracyBefore[0]}% with a loss of {accuracyBefore[1]}")
model, (x_train, y_train, y_train_old), metadata = trainEpochs((x_train, y_train, y_train_old), (x_test, y_test), 1, verbose = 1, augmentationForModification=10, subEpochs = 50, subQValue = 0.7, monoepoch = True)
displayGraph(metadata)
accuracyAfter = getValAccuracy(x_train, y_train, x_test, y_test, q = 0.7)
print(f"Validation accuracy after dataset modification: {accuracyAfter[0]}% with a loss of {accuracyAfter[1]}")

#accuracyBefore = getValAccuracy(x_train, y_train, x_test, y_test)
#print(f"Validation accuracy before dataset modification: {accuracyBefore[0]}% with a loss of {accuracyBefore[1]}")
#model1, (x_train, y_train, y_train_old), metadata1 = trainEpochs((x_train, y_train, y_train_old), (x_test, y_test), MAIN_EPOCHS, verbose = 1, mode="delete")
#accuracyAfter = getValAccuracy(x_train, y_train, x_test, y_test)
#print(f"Validation accuracy after dataset modification: {accuracyAfter[0]}% with a loss of {accuracyAfter[1]}")

#displayGraph(metadata1)

# %%
print(metadata)
print(len(images))
correct, incorrect = getCorrectSample(images)
print(len(correct))
print(len(incorrect))
showSample(correct, 16)
showSample(incorrect, 16)

# %%
#metadata = {'val accuracy': [91.36666655540466, 93.7166690826416, 94.23333406448364, 94.81666684150696, 95.45000195503235, 96.31666541099548, 96.78333401679993, 96.14999890327454], 'val loss': [0.9319291114807129, 0.5999569892883301, 0.36166685819625854, 0.21822355687618256, 0.17234396934509277, 0.12887966632843018, 0.11454400420188904, 0.13207554817199707], 'dataset accuracy before': [50.59259259259259, 49.407407407407405, 66.4074074074074, 66.77407407407408, 91.40370370370371, 91.35185185185185, 95.64444444444445, 96.08148148148148], 'dataset accuracy after': [57.733333333333334, 75.44814814814815, 89.22592592592594, 93.52962962962962, 95.25925925925925, 96.46666666666667, 96.57777777777777, 96.87037037037037], 'dataset correct relabelling': [7.151851851851852, 26.185185185185183, 23.18148148148148, 27.48888888888889, 4.588888888888889, 5.774074074074074, 1.5962962962962963, 1.6481481481481481], 'dataset incorrect relabelling': [0.011111111111111112, 0.14444444444444443, 0.362962962962963, 0.7333333333333333, 0.7333333333333333, 0.6592592592592592, 0.662962962962963, 0.8592592592592593], 'total dataset accuracy': [53.57037037037037, 66.59074074074074, 78.0, 91.37777777777778, 93.30555555555556, 95.86296296296297, 96.32962962962964, 96.72407407407407]} # Remove me

# %%
displayGraph(metadata)

# %%
print(labels)

# %%
images = getImages()
images = random.sample(images, 10000)
print("found", len(images), "images!")
images, val_images = splitTrainVal(images, 0.1)
#showSample(images, 16)
#showSample(val_images, 16)
images, changes = swapLabels(images, 0.5)
print("Labeling accuracy at start:", getLabelingAccuracy(images))
#showSample(changes, 16)

model, images1, metadata = trainEpochs(copy.deepcopy(images), MAIN_EPOCHS, verbose = 1)

displayGraph(metadata)

model1, images1, metadata1 = trainEpochs(copy.deepcopy(images), MAIN_EPOCHS, verbose = 1, mode="delete")

displayGraph(metadata1)
print(metadatalist)

# %%
for metadata in metadatalist:
  displayGraph(metadata)
