# %%
# !git clone https://github.com/Yetiowner/Rouse
# !cd Rouse
# !python Rouse/setup.py install
# Out:
# Cloning into 'Rouse'...
# remote: Enumerating objects: 326, done.
# remote: Counting objects: 100% (167/167), done.
# remote: Compressing objects: 100% (115/115), done.
# remote: Total 326 (delta 105), reused 110 (delta 51), pack-reused 159
# Receiving objects: 100% (326/326), 17.44 MiB | 9.62 MiB/s, done.
# Resolving deltas: 100% (199/199), done.
# running install
# /usr/local/lib/python3.9/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/setuptools/command/easy_install.py:144: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# running bdist_egg
# running egg_info
# creating Rouse.egg-info
# writing Rouse.egg-info/PKG-INFO
# writing dependency_links to Rouse.egg-info/dependency_links.txt
# writing requirements to Rouse.egg-info/requires.txt
# writing top-level names to Rouse.egg-info/top_level.txt
# writing manifest file 'Rouse.egg-info/SOURCES.txt'
# reading manifest file 'Rouse.egg-info/SOURCES.txt'
# writing manifest file 'Rouse.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/Rouse
# copying Rouse/modelResNet.py -> build/lib/Rouse
# copying Rouse/setup.py -> build/lib/Rouse
# copying Rouse/__init__.py -> build/lib/Rouse
# copying Rouse/unpickleds.py -> build/lib/Rouse
# copying Rouse/dataClean.py -> build/lib/Rouse
# copying Rouse/usage.py -> build/lib/Rouse
# copying Rouse/test.py -> build/lib/Rouse
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/Rouse
# copying build/lib/Rouse/modelResNet.py -> build/bdist.linux-x86_64/egg/Rouse
# copying build/lib/Rouse/setup.py -> build/bdist.linux-x86_64/egg/Rouse
# copying build/lib/Rouse/__init__.py -> build/bdist.linux-x86_64/egg/Rouse
# copying build/lib/Rouse/unpickleds.py -> build/bdist.linux-x86_64/egg/Rouse
# copying build/lib/Rouse/dataClean.py -> build/bdist.linux-x86_64/egg/Rouse
# copying build/lib/Rouse/usage.py -> build/bdist.linux-x86_64/egg/Rouse
# copying build/lib/Rouse/test.py -> build/bdist.linux-x86_64/egg/Rouse
# byte-compiling build/bdist.linux-x86_64/egg/Rouse/modelResNet.py to modelResNet.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/Rouse/setup.py to setup.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/Rouse/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/Rouse/unpickleds.py to unpickleds.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/Rouse/dataClean.py to dataClean.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/Rouse/usage.py to usage.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/Rouse/test.py to test.cpython-39.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying Rouse.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying Rouse.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying Rouse.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying Rouse.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying Rouse.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating dist
# creating 'dist/Rouse-0.1-py3.9.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing Rouse-0.1-py3.9.egg
# Copying Rouse-0.1-py3.9.egg to /usr/local/lib/python3.9/dist-packages
# Adding Rouse 0.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.9/dist-packages/Rouse-0.1-py3.9.egg
# Processing dependencies for Rouse==0.1
# Searching for tensorflow==2.12.0
# Best match: tensorflow 2.12.0
# Adding tensorflow 2.12.0 to easy-install.pth file
# Installing estimator_ckpt_converter script to /usr/local/bin
# Installing import_pb_to_tensorboard script to /usr/local/bin
# Installing saved_model_cli script to /usr/local/bin
# Installing tensorboard script to /usr/local/bin
# Installing tf_upgrade_v2 script to /usr/local/bin
# Installing tflite_convert script to /usr/local/bin
# Installing toco script to /usr/local/bin
# Installing toco_from_protos script to /usr/local/bin
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for numpy==1.22.4
# Best match: numpy 1.22.4
# Adding numpy 1.22.4 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.9 script to /usr/local/bin
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for matplotlib==3.7.1
# Best match: matplotlib 3.7.1
# Adding matplotlib 3.7.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for opencv-python==4.7.0.72
# Best match: opencv-python 4.7.0.72
# Adding opencv-python 4.7.0.72 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for keras==2.12.0
# Best match: keras 2.12.0
# Adding keras 2.12.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for tensorflow-io-gcs-filesystem==0.32.0
# Best match: tensorflow-io-gcs-filesystem 0.32.0
# Adding tensorflow-io-gcs-filesystem 0.32.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for wrapt==1.14.1
# Best match: wrapt 1.14.1
# Adding wrapt 1.14.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for typing-extensions==4.5.0
# Best match: typing-extensions 4.5.0
# Adding typing-extensions 4.5.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for termcolor==2.2.0
# Best match: termcolor 2.2.0
# Adding termcolor 2.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for tensorflow-estimator==2.12.0
# Best match: tensorflow-estimator 2.12.0
# Adding tensorflow-estimator 2.12.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for tensorboard==2.12.1
# Best match: tensorboard 2.12.1
# Adding tensorboard 2.12.1 to easy-install.pth file
# Installing tensorboard script to /usr/local/bin
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for six==1.16.0
# Best match: six 1.16.0
# Adding six 1.16.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for setuptools==67.6.1
# Best match: setuptools 67.6.1
# Adding setuptools 67.6.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for protobuf==3.20.3
# Best match: protobuf 3.20.3
# Adding protobuf 3.20.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for packaging==23.0
# Best match: packaging 23.0
# Adding packaging 23.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for opt-einsum==3.3.0
# Best match: opt-einsum 3.3.0
# Adding opt-einsum 3.3.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for libclang==16.0.0
# Best match: libclang 16.0.0
# Adding libclang 16.0.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for jax==0.4.7
# Best match: jax 0.4.7
# Adding jax 0.4.7 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for h5py==3.8.0
# Best match: h5py 3.8.0
# Adding h5py 3.8.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for grpcio==1.53.0
# Best match: grpcio 1.53.0
# Adding grpcio 1.53.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for google-pasta==0.2.0
# Best match: google-pasta 0.2.0
# Adding google-pasta 0.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for gast==0.4.0
# Best match: gast 0.4.0
# Adding gast 0.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for flatbuffers==23.3.3
# Best match: flatbuffers 23.3.3
# Adding flatbuffers 23.3.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for astunparse==1.6.3
# Best match: astunparse 1.6.3
# Adding astunparse 1.6.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for absl-py==1.4.0
# Best match: absl-py 1.4.0
# Adding absl-py 1.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for importlib-resources==5.12.0
# Best match: importlib-resources 5.12.0
# Adding importlib-resources 5.12.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for python-dateutil==2.8.2
# Best match: python-dateutil 2.8.2
# Adding python-dateutil 2.8.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for pyparsing==3.0.9
# Best match: pyparsing 3.0.9
# Adding pyparsing 3.0.9 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for Pillow==8.4.0
# Best match: Pillow 8.4.0
# Adding Pillow 8.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for kiwisolver==1.4.4
# Best match: kiwisolver 1.4.4
# Adding kiwisolver 1.4.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for fonttools==4.39.3
# Best match: fonttools 4.39.3
# Adding fonttools 4.39.3 to easy-install.pth file
# Installing fonttools script to /usr/local/bin
# Installing pyftmerge script to /usr/local/bin
# Installing pyftsubset script to /usr/local/bin
# Installing ttx script to /usr/local/bin
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for cycler==0.11.0
# Best match: cycler 0.11.0
# Adding cycler 0.11.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for contourpy==1.0.7
# Best match: contourpy 1.0.7
# Adding contourpy 1.0.7 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for wheel==0.40.0
# Best match: wheel 0.40.0
# Adding wheel 0.40.0 to easy-install.pth file
# Installing wheel script to /usr/local/bin
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for Werkzeug==2.2.3
# Best match: Werkzeug 2.2.3
# Adding Werkzeug 2.2.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for tensorboard-plugin-wit==1.8.1
# Best match: tensorboard-plugin-wit 1.8.1
# Adding tensorboard-plugin-wit 1.8.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for tensorboard-data-server==0.7.0
# Best match: tensorboard-data-server 0.7.0
# Adding tensorboard-data-server 0.7.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for requests==2.27.1
# Best match: requests 2.27.1
# Adding requests 2.27.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for Markdown==3.4.3
# Best match: Markdown 3.4.3
# Adding Markdown 3.4.3 to easy-install.pth file
# Installing markdown_py script to /usr/local/bin
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for google-auth-oauthlib==1.0.0
# Best match: google-auth-oauthlib 1.0.0
# Adding google-auth-oauthlib 1.0.0 to easy-install.pth file
# Installing google-oauthlib-tool script to /usr/local/bin
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for google-auth==2.17.2
# Best match: google-auth 2.17.2
# Adding google-auth 2.17.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for scipy==1.10.1
# Best match: scipy 1.10.1
# Adding scipy 1.10.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for ml-dtypes==0.0.4
# Best match: ml-dtypes 0.0.4
# Adding ml-dtypes 0.0.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for zipp==3.15.0
# Best match: zipp 3.15.0
# Adding zipp 3.15.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for MarkupSafe==2.1.2
# Best match: MarkupSafe 2.1.2
# Adding MarkupSafe 2.1.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for idna==3.4
# Best match: idna 3.4
# Adding idna 3.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for charset-normalizer==2.0.12
# Best match: charset-normalizer 2.0.12
# Adding charset-normalizer 2.0.12 to easy-install.pth file
# Installing normalizer script to /usr/local/bin
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for certifi==2022.12.7
# Best match: certifi 2022.12.7
# Adding certifi 2022.12.7 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for urllib3==1.26.15
# Best match: urllib3 1.26.15
# Adding urllib3 1.26.15 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for importlib-metadata==6.2.0
# Best match: importlib-metadata 6.2.0
# Adding importlib-metadata 6.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for requests-oauthlib==1.3.1
# Best match: requests-oauthlib 1.3.1
# Adding requests-oauthlib 1.3.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for rsa==4.9
# Best match: rsa 4.9
# Adding rsa 4.9 to easy-install.pth file
# Installing pyrsa-decrypt script to /usr/local/bin
# Installing pyrsa-encrypt script to /usr/local/bin
# Installing pyrsa-keygen script to /usr/local/bin
# Installing pyrsa-priv2pub script to /usr/local/bin
# Installing pyrsa-sign script to /usr/local/bin
# Installing pyrsa-verify script to /usr/local/bin
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for pyasn1-modules==0.2.8
# Best match: pyasn1-modules 0.2.8
# Adding pyasn1-modules 0.2.8 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for cachetools==5.3.0
# Best match: cachetools 5.3.0
# Adding cachetools 5.3.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for oauthlib==3.2.2
# Best match: oauthlib 3.2.2
# Adding oauthlib 3.2.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for pyasn1==0.4.8
# Best match: pyasn1 0.4.8
# Adding pyasn1 0.4.8 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Finished processing dependencies for Rouse==0.1

# %%
from Rouse import *
from tensorflow.keras.datasets import cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()


print("found", len(x_train), "images!")
showSample(x_test, y_test, 16)
y_train, y_train_old = swapLabels(y_train, 0.4)

print("Labeling accuracy at start:", getLabelingAccuracy(y_train, y_train_old))
#showSample(changes, 16)

#accuracyBefore = getValAccuracy(x_train, y_train, x_test, y_test)
#print(f"Validation accuracy before dataset modification: {accuracyBefore[0]}% with a loss of {accuracyBefore[1]}")
model, (x_train, y_train, y_train_old), metadata = trainEpochs((x_train, y_train, y_train_old), (x_test, y_test), 1, verbose = 1, augmentationForModification=10)
displayGraph(metadata)
accuracyAfter = getValAccuracy(x_train, y_train, x_test, y_test)
print(f"Validation accuracy after dataset modification: {accuracyAfter[0]}% with a loss of {accuracyAfter[1]}")

#accuracyBefore = getValAccuracy(x_train, y_train, x_test, y_test)
#print(f"Validation accuracy before dataset modification: {accuracyBefore[0]}% with a loss of {accuracyBefore[1]}")
#model1, (x_train, y_train, y_train_old), metadata1 = trainEpochs((x_train, y_train, y_train_old), (x_test, y_test), MAIN_EPOCHS, verbose = 1, mode="delete")
#accuracyAfter = getValAccuracy(x_train, y_train, x_test, y_test)
#print(f"Validation accuracy after dataset modification: {accuracyAfter[0]}% with a loss of {accuracyAfter[1]}")

#displayGraph(metadata1)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 15s 0us/step
# found 50000 images!
# /usr/local/lib/python3.9/dist-packages/matplotlib/text.py:1279: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# (50000, 1)
# Labeling accuracy at start: 60.0
# Epoch 1/41
# 391/391 [==============================] - 38s 43ms/step - loss: 3.1204 - accuracy: 0.2007 - val_loss: 2.8971 - val_accuracy: 0.3614 - lr: 0.0100
# Epoch 2/41
# 391/391 [==============================] - 15s 39ms/step - loss: 3.0461 - accuracy: 0.2494 - val_loss: 2.7899 - val_accuracy: 0.3914 - lr: 0.0100
# Epoch 3/41
# 391/391 [==============================] - 15s 39ms/step - loss: 2.9905 - accuracy: 0.2793 - val_loss: 2.7205 - val_accuracy: 0.4231 - lr: 0.0100
# Epoch 4/41
# 391/391 [==============================] - 15s 38ms/step - loss: 2.9417 - accuracy: 0.3007 - val_loss: 2.6737 - val_accuracy: 0.4243 - lr: 0.0100
# Epoch 5/41
# 391/391 [==============================] - 15s 39ms/step - loss: 2.8970 - accuracy: 0.3116 - val_loss: 2.6324 - val_accuracy: 0.4369 - lr: 0.0100
# Epoch 6/41
# 391/391 [==============================] - 15s 40ms/step - loss: 2.8560 - accuracy: 0.3265 - val_loss: 2.5246 - val_accuracy: 0.4805 - lr: 0.0100
# Epoch 7/41
# 391/391 [==============================] - 15s 38ms/step - loss: 2.8113 - accuracy: 0.3439 - val_loss: 2.4415 - val_accuracy: 0.5467 - lr: 0.0100
# Epoch 8/41
# 391/391 [==============================] - 15s 39ms/step - loss: 2.7729 - accuracy: 0.3537 - val_loss: 2.6182 - val_accuracy: 0.3974 - lr: 0.0100
# Epoch 9/41
# 391/391 [==============================] - 15s 39ms/step - loss: 2
41
# 391/391 [==============================] - 15s 39ms/step - loss: 2.1498 - accuracy: 0.4790 - val_loss: 1.8286 - val_accuracy: 0.6225 - lr: 0.0100
# Epoch 32/41
# 391/391 [==============================] - 15s 39ms/step - loss: 2.1295 - accuracy: 0.4817 - val_loss: 1.7673 - val_accuracy: 0.6368 - lr: 0.0100
# Epoch 33/41
# 391/391 [==============================] - 15s 39ms/step - loss: 2.1062 - accuracy: 0.4854 - val_loss: 1.7490 - val_accuracy: 0.6421 - lr: 0.0100
# Epoch 34/41
# 391/391 [==============================] - 15s 39ms/step - loss: 2.0859 - accuracy: 0.4870 - val_loss: 1.6692 - val_accuracy: 0.6849 - lr: 0.0100
# Epoch 35/41
# 391/391 [==============================] - 15s 39ms/step - loss: 2.0626 - accuracy: 0.4943 - val_loss: 1.6769 - val_accuracy: 0.6678 - lr: 0.0100
# Epoch 36/41
# 391/391 [==============================] - 16s 40ms/step - loss: 2.0462 - accuracy: 0.4967 - val_loss: 1.7001 - val_accuracy: 0.6585 - lr: 0.0100
# Epoch 37/41
# 391/391 [==============================] - 16s 41ms/step - loss: 2.0265 - accuracy: 0.4964 - val_loss: 1.5856 - val_accuracy: 0.7062 - lr: 0.0100
# Epoch 38/41
# 391/391 [==============================] - 16s 41ms/step - loss: 2.0085 - accuracy: 0.4999 - val_loss: 1.6318 - val_accuracy: 0.6824 - lr: 0.0100
# Epoch 39/41
# 391/391 [==============================] - 16s 41ms/step - loss: 1.9837 - accuracy: 0.5072 - val_loss: 1.6111 - val_accuracy: 0.6823 - lr: 0.0100
# Epoch 40/41
# 782/782 [==============================] - 5s 5ms/step
# 391/391 [==============================] - 22s 56ms/step - loss: 1.9693 - accuracy: 0.5074 - val_loss: 1.5785 - val_accuracy: 0.7003 - lr: 0.0100 - pruning_ratio: 0.1000 - num_examples_pruned: 2500.0000
# Epoch 41/41
# 391/391 [==============================] - 15s 39ms/step - loss: 1.7771 - accuracy: 0.5941 - val_loss: 1.3676 - val_accuracy: 0.7966 - lr: 1.0000e-03
# 782/782 [==============================] - 4s 5ms/step
# 782/782 [==============================] - 4s 5ms/step
# 782/782 [==============================] - 4s 5ms/step
# 782/782 [==============================] - 4s 5ms/step
# 782/782 [==============================] - 4s 5ms/step
# 782/782 [==============================] - 4s 5ms/step
# 782/782 [==============================] - 4s 5ms/step
# 782/782 [==============================] - 4s 5ms/step
# 782/782 [==============================] - 4s 5ms/step
# 782/782 [==============================] - 4s 5ms/step
# 0
# 1250
# 2500
# 3750
# 5000
# 6250
# 7500
# 8750
# 10000
# 11250
# 12500
# 13750
# 15000
# 16250
# 17500
# 18750
# 20000
# 21250
# 22500
# 23750
# ======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# | Elapsed: 0:13:43 | Epoch 1 |  First half epoch | Model training progress: ========================================= 41/41 | Validation accuracy: 79.66% | Validation loss: 1.368 | Dataset modification progress: ==================== 25000/25000 | Dataset half accuracy before half epoch: 60.25% | Dataset half accuracy after half epoch: 81.80% | Correct relabelling: 23.06% | Incorrect relabelling:  1.51% | Neutral relabelling:  1.43% | Total dataset accuracy: 70.77% |
# ======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# Epoch 1/41
# 391/391 [==============================] - 29s 44ms/step - loss: 3.1250 - accuracy: 0.1967 - val_loss: 2.8865 - val_accuracy: 0.3571 - lr: 0.0100
# Epoch 2/41
# 391/391 [==============================] - 16s 42ms/step - loss: 3.0500 - accuracy: 0.2462 - val_loss: 2.8112 - val_accuracy: 0.3653 - lr: 0.0100
# Epoch 3/41
# 391/391 [==============================] - 16s 41ms/step - loss: 2.9952 - accuracy: 0.2697 - val_loss: 2.7416 - val_accuracy: 0.3997 - lr: 0.0100
# Epoch 4/41
# 391/391 [==============================] - 16s 41ms/step - loss: 2.9480 - accuracy: 0.2904 - val_loss: 2.6801 - val_accuracy: 0.4239 - lr: 0.0100
# Epoch 5/41
# 391/391 [==============================] - 16s 42ms/step - loss: 2.9030 - accuracy: 0.3054 - val_loss: 2.5573 - val_accuracy: 0.4930 - lr: 0.0100
# Epoch 6/41
# 391/391 [==============================] - 16s 41ms/step - loss: 2.8618 - accuracy: 0.3227 - val_loss: 2.5423 - val_accuracy: 0.4738 - lr: 0.0100
# Epoch 7/41
# 391/391 [==============================] - 16s 41ms/step - loss: 2
41
# 391/391 [==============================] - 16s 41ms/step - loss: 2.1405 - accuracy: 0.4835 - val_loss: 1.7879 - val_accuracy: 0.6405 - lr: 0.0100
# Epoch 32/41
# 391/391 [==============================] - 16s 41ms/step - loss: 2.1164 - accuracy: 0.4895 - val_loss: 1.7398 - val_accuracy: 0.6540 - lr: 0.0100
# Epoch 33/41
# 391/391 [==============================] - 16s 41ms/step - loss: 2.0997 - accuracy: 0.4914 - val_loss: 1.6744 - val_accuracy: 0.6724 - lr: 0.0100
# Epoch 34/41
# 391/391 [==============================] - 16s 41ms/step - loss: 2.0770 - accuracy: 0.4955 - val_loss: 1.7413 - val_accuracy: 0.6364 - lr: 0.0100
# Epoch 35/41
# 391/391 [==============================] - 16s 41ms/step - loss: 2.0540 - accuracy: 0.5007 - val_loss: 1.6052 - val_accuracy: 0.7021 - lr: 0.0100
# Epoch 36/41
# 391/391 [==============================] - 16s 41ms/step - loss: 2.0373 - accuracy: 0.5001 - val_loss: 1.6365 - val_accuracy: 0.6777 - lr: 0.0100
# Epoch 37/41
# 391/391 [==============================] - 16s 41ms/step - loss: 2.0189 - accuracy: 0.5038 - val_loss: 1.6364 - val_accuracy: 0.6980 - lr: 0.0100
# Epoch 38/41
# 391/391 [==============================] - 16s 41ms/step - loss: 1.9989 - accuracy: 0.5055 - val_loss: 1.7303 - val_accuracy: 0.6187 - lr: 0.0100
# Epoch 39/41
# 391/391 [==============================] - 16s 41ms/step - loss: 1.9763 - accuracy: 0.5098 - val_loss: 1.5197 - val_accuracy: 0.7169 - lr: 0.0100
# Epoch 40/41
# 782/782 [==============================] - 5s 5ms/step
# 391/391 [==============================] - 22s 55ms/step - loss: 1.9608 - accuracy: 0.5114 - val_loss: 1.5167 - val_accuracy: 0.7372 - lr: 0.0100 - pruning_ratio: 0.1000 - num_examples_pruned: 2500.0000
# Epoch 41/41
# 391/391 [==============================] - 15s 38ms/step - loss: 1.7667 - accuracy: 0.5992 - val_loss: 1.3775 - val_accuracy: 0.7966 - lr: 1.0000e-03
# 782/782 [==============================] - 4s 5ms/step
# 782/782 [==============================] - 4s 5ms/step
# 782/782 [==============================] - 4s 5ms/step
# 782/782 [==============================] - 4s 5ms/step
# 782/782 [==============================] - 4s 5ms/step
# 782/782 [==============================] - 4s 5ms/step
# 782/782 [==============================] - 4s 5ms/step
# 782/782 [==============================] - 4s 5ms/step
# 782/782 [==============================] - 4s 5ms/step
# 782/782 [==============================] - 4s 5ms/step
# 0
# 1250
# 2500
# 3750
# 5000
# 6250
# 7500
# 8750
# 10000
# 11250
# 12500
# 13750
# 15000
# 16250
# 17500
# 18750
# 20000
# 21250
# 22500
# 23750
# ======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# | Elapsed: 0:14:02 | Epoch 1 | Second half epoch | Model training progress: ========================================= 41/41 | Validation accuracy: 79.63% | Validation loss: 1.378 | Dataset modification progress: ==================== 25000/25000 | Dataset half accuracy before half epoch: 59.75% | Dataset half accuracy after half epoch: 80.70% | Correct relabelling: 22.34% | Incorrect relabelling:  1.39% | Neutral relabelling:  1.16% | Total dataset accuracy: 81.25% |
# ======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# Epoch 1/120
# 391/391 [==============================] - 42s 75ms/step - loss: 2.9505 - accuracy: 0.3120 - val_loss: 2.7600 - val_accuracy: 0.3982 - lr: 0.0100
# Epoch 2/120
# 391/391 [==============================] - 28s 71ms/step - loss: 2.7297 - accuracy: 0.4339 - val_loss: 2.5782 - val_accuracy: 0.4922 - lr: 0.0100
# Epoch 3/120
# 391/391 [==============================] - 28s 70ms/step - loss: 2.5861 - accuracy: 0.5061 - val_loss: 2.6223 - val_accuracy: 0.4627 - lr: 0.0100
# Epoch 4/120
# 391/391 [==============================] - 28s 71ms/step - loss: 2.4821 - accuracy: 0.5525 - val_loss: 2.5072 - val_accuracy: 0.5145 - lr: 0.0100
# Epoch 5/120
# 391/391 [==============================] - 28s 71ms/step - loss: 2.3954 - accuracy: 0.5901 - val_loss: 2.4636 - val_accuracy: 0.5449 - lr: 0.0100
120
# 391/391 [==============================] - 28s 71ms/step - loss: 1.6704 - accuracy: 0.7552 - val_loss: 1.6286 - val_accuracy: 0.7508 - lr: 0.0100
# Epoch 27/120
# 391/391 [==============================] - 28s 71ms/step - loss: 1.6492 - accuracy: 0.7562 - val_loss: 1.5745 - val_accuracy: 0.7667 - lr: 0.0100
# Epoch 28/120
# 391/391 [==============================] - 28s 71ms/step - loss: 1.6267 - accuracy: 0.7597 - val_loss: 1.6372 - val_accuracy: 0.7276 - lr: 0.0100
# Epoch 29/120
# 391/391 [==============================] - 28s 71ms/step - loss: 1.6093 - accuracy: 0.7612 - val_loss: 1.6073 - val_accuracy: 0.7427 - lr: 0.0100
# Epoch 30/120
# 391/391 [==============================] - 28s 72ms/step - loss: 1.5905 - accuracy: 0.7615 - val_loss: 1.5284 - val_accuracy: 0.7696 - lr: 0.0100
# Epoch 31/120
# 391/391 [==============================] - 28s 71ms/step - loss: 1.5653 - accuracy: 0.7663 - val_loss: 1.5090 - val_accuracy: 0.7700 - lr: 0.0100
# Epoch 32/120
# 391/391 [==============================] - 28s 72ms/step - loss: 1.5459 - accuracy: 0.7690 - val_loss: 1.5374 - val_accuracy: 0.7520 - lr: 0.0100
# Epoch 33/120
# 391/391 [==============================] - 28s 70ms/step - loss: 1.5297 - accuracy: 0.7696 - val_loss: 1.4617 - val_accuracy: 0.7820 - lr: 0.0100
# Epoch 34/120
# 391/391 [==============================] - 28s 72ms/step - loss: 1.5093 - accuracy: 0.7715 - val_loss: 1.4166 - val_accuracy: 0.8008 - lr: 0.0100
# Epoch 35/120
# 391/391 [==============================] - 28s 70ms/step - loss: 1.4921 - accuracy: 0.7731 - val_loss: 1.4206 - val_accuracy: 0.7846 - lr: 0.0100
# Epoch 36/120
# 391/391 [==============================] - 28s 71ms/step - loss: 1.4730 - accuracy: 0.7765 - val_loss: 1.3658 - val_accuracy: 0.8086 - lr: 0.0100
# Epoch 37/120
# 391/391 [==============================] - 28s 71ms/step - loss: 1.4543 - accuracy: 0.7770 - val_loss: 1.5716 - val_accuracy: 0.6985 - lr: 0.0100
# Epoch 38/120
# 391/391 [==============================] - 28s 71ms/step - loss: 1.4393 - accuracy: 0.7781 - val_loss: 1.3323 - val_accuracy: 0.8110 - lr: 0.0100
# Epoch 39/120
# 391/391 [==============================] - 28s 71ms/step - loss: 1.4207 - accuracy: 0.7813 - val_loss: 1.3930 - val_accuracy: 0.7750 - lr: 0.0100
# Epoch 40/120
# 1563/1563 [==============================] - 9s 5ms/step
# 391/391 [==============================] - 39s 98ms/step - loss: 1.4058 - accuracy: 0.7813 - val_loss: 1.3519 - val_accuracy: 0.7863 - lr: 0.0100 - pruning_ratio: 0.1000 - num_examples_pruned: 5000.0000
# Epoch 41/120
# 391/391 [==============================] - 26s 66ms/step - loss: 1.1776 - accuracy: 0.8827 - val_loss: 1.2295 - val_accuracy: 0.8499 - lr: 1.0000e-03
# Epoch 42/120
# 391/391 [==============================] - 25s 64ms/step - loss: 1.1614 - accuracy: 0.8898 - val_loss: 1.2170 - val_accuracy: 0.8532 - lr: 1.0000e-03
# Epoch 43/120
# 391/391 [==============================] - 25s 64ms/step - loss: 1.1545 - accuracy: 0.8925 - val_loss: 1.2247 - val_accuracy: 0.8496 - lr: 1.0000e-03
# Epoch 44/120
# 391/391 [==============================] - 25s 64ms/step - loss: 1.1496 - accuracy: 0.8936 - val_loss: 1.2126 - val_accuracy: 0.8538 - lr: 1.0000e-03
# Epoch 45/120
# 391/391 [==============================] - 25s 65ms/step - loss: 1.1458 - accuracy: 0.8950 - val_loss: 1.2234 - val_accuracy: 0.8500 - lr: 1.0000e-03
# Epoch 46/120
# 391/391 [==============================] - 25s 64ms/step - loss: 1.1409 - accuracy: 0.8972 - val_loss: 1.2089 - val_accuracy: 0.8567 - lr: 1.0000e-03
# Epoch 47/120
# 391/391 [==============================] - 25s 65ms/step - loss: 1.1367 - accuracy: 0.8973 - val_loss: 1.2420 - val_accuracy: 0.8376 - lr: 1.0000e-03
# Epoch 48/120
# 391/391 [==============================] - 25s 64ms/step - loss: 1.1366 - accuracy: 0.8970 - val_loss: 1.2167 - val_accuracy: 0.8499 - lr: 1.0000e-03
# Epoch 49/120
# 391/391 [==============================] - 25s 64ms/step - loss: 1.1319 - accuracy: 0.9000 - val_loss: 1.2319 - val_accuracy: 0.8425 - lr: 1.0000e-03
# Epoch 50/120
# 1407/1407 [==============================] - 7s 5ms/step
# 391/391 [==============================] - 34s 87ms/step - loss: 1.1273 - accuracy: 0.9011 - val_loss: 1.2258 - val_accuracy: 0.8442 - lr: 1.0000e-03 - pruning_ratio: 0.1000 - num_examples_pruned: 4500.0000
# Epoch 51/120
# 391/391 [==============================] - 24s 61ms/step - loss: 0.9882 - accuracy: 0.9703 - val_loss: 1.2104 - val_accuracy: 0.8524 - lr: 1.0000e-03
# Epoch 52/120
# 391/391 [==============================] - 23s 59ms/step - loss: 0.9856 - accuracy: 0.9694 - val_loss: 1.2271 - val_accuracy: 0.8429 - lr: 1.0000e-03
# Epoch 53/120
# 391/391 [==============================] - 23s 59ms/step - loss: 0.9817 - accuracy: 0.9709 - val_loss: 1.2235 - val_accuracy: 0.8445 - lr: 1.0000e-03
# Epoch 54/120
# 391/391 [==============================] - 23s 59ms/step - loss: 0.9807 - accuracy: 0.9704 - val_loss: 1.2270 - val_accuracy: 0.8425 - lr: 1.0000e-03
# Epoch 55/120
# 391/391 [==============================] - 23s 59ms/step - loss: 0.9759 - accuracy: 0.9728 - val_loss: 1.2043 - val_accuracy: 0.8532 - lr: 1.0000e-03
# Epoch 56/120
# 391/391 [==============================] - 23s 59ms/step - loss: 0.9733 - accuracy: 0.9727 - val_loss: 1.2206 - val_accuracy: 0.8437 - lr: 1.0000e-03
# Epoch 57/120
# 391/391 [==============================] - 23s 59ms/step - loss: 0.9702 - accuracy: 0.9739 - val_loss: 1.2184 - val_accuracy: 0.8459 - lr: 1.0000e-03
# Epoch 58/120
# 391/391 [==============================] - 23s 58ms/step - loss: 0.9695 - accuracy: 0.9731 - val_loss: 1.2209 - val_accuracy: 0.8438 - lr: 1.0000e-03
# Epoch 59/120
# 391/391 [==============================] - 23s 59ms/step - loss: 0.9671 - accuracy: 0.9736 - val_loss: 1.2090 - val_accuracy: 0.8492 - lr: 1.0000e-03
# Epoch 60/120
# 1266/1266 [==============================] - 6s 5ms/step
# 391/391 [==============================] - 31s 80ms/step - loss: 0.9650 - accuracy: 0.9744 - val_loss: 1.1973 - val_accuracy: 0.8544 - lr: 1.0000e-03 - pruning_ratio: 0.1000 - num_examples_pruned: 4050.0000
# Epoch 61/120
# 391/391 [==============================] - 22s 56ms/step - loss: 0.9381 - accuracy: 0.9869 - val_loss: 1.2066 - val_accuracy: 0.8494 - lr: 1.0000e-03
# Epoch 62/120
# 391/391 [==============================] - 21s 54ms/step - loss: 0.9349 - accuracy: 0.9883 - val_loss: 1.2164 - val_accuracy: 0.8422 - lr: 1.0000e-03
# Epoch 63/120
# 391/391 [==============================] - 21s 53ms/step - loss: 0.9341 - accuracy: 0.9881 - val_loss: 1.2089 - val_accuracy: 0.8478 - lr: 1.0000e-03
# Epoch 64/120
# 391/391 [==============================] - 21s 53ms/step - loss: 0.9320 - accuracy: 0.9885 - val_loss: 1.2056 - val_accuracy: 0.8476 - lr: 1.0000e-03
# Epoch 65/120
# 391/391 [==============================] - 21s 54ms/step - loss: 0.9303 - accuracy: 0.9886 - val_loss: 1.2026 - val_accuracy: 0.8510 - lr: 1.0000e-03
# Epoch 66/120
# 391/391 [==============================] - 21s 53ms/step - loss: 0.9284 - accuracy: 0.9890 - val_loss: 1.2054 - val_accuracy: 0.8476 - lr: 1.0000e-03
# Epoch 67/120
# 391/391 [==============================] - 21s 53ms/step - loss: 0.9260 - accuracy: 0.9903 - val_loss: 1.1976 - val_accuracy: 0.8503 - lr: 1.0000e-03
# Epoch 68/120
# 391/391 [==============================] - 21s 54ms/step - loss: 0.9270 - accuracy: 0.9885 - val_loss: 1.1976 - val_accuracy: 0.8497 - lr: 1.0000e-03
# Epoch 69/120
# 391/391 [==============================] - 21s 53ms/step - loss: 0.9236 - accuracy: 0.9902 - val_loss: 1.1998 - val_accuracy: 0.8482 - lr: 1.0000e-03
# Epoch 70/120
# 1140/1140 [==============================] - 6s 5ms/step
# 391/391 [==============================] - 28s 72ms/step - loss: 0.9233 - accuracy: 0.9898 - val_loss: 1.2090 - val_accuracy: 0.8416 - lr: 1.0000e-03 - pruning_ratio: 0.1000 - num_examples_pruned: 3645.0000
# Epoch 71/120
# 391/391 [==============================] - 20s 50ms/step - loss: 0.9140 - accuracy: 0.9933 - val_loss: 1.2111 - val_accuracy: 0.8429 - lr: 1.0000e-03
# Epoch 72/120
# 391/391 [==============================] - 19s 48ms/step - loss: 0.9135 - accuracy: 0.9934 - val_loss: 1.2061 - val_accuracy: 0.8436 - lr: 1.0000e-03
# Epoch 73/120
# 391/391 [==============================] - 19s 49ms/step - loss: 0.9125 - accuracy: 0.9932 - val_loss: 1.2106 - val_accuracy: 0.8419 - lr: 1.0000e-03
# Epoch 74/120
# 391/391 [==============================] - 19s 48ms/step - loss: 0.9096 - accuracy: 0.9941 - val_loss: 1.2184 - val_accuracy: 0.8360 - lr: 1.0000e-03
# Epoch 75/120
# 391/391 [==============================] - 19s 49ms/step - loss: 0.9092 - accuracy: 0.9940 - val_loss: 1.2107 - val_accuracy: 0.8404 - lr: 1.0000e-03
# Epoch 76/120
# 391/391 [==============================] - 19s 49ms/step - loss: 0.9087 - accuracy: 0.9940 - val_loss: 1.2102 - val_accuracy: 0.8384 - lr: 1.0000e-03
# Epoch 77/120
# 391/391 [==============================] - 19s 49ms/step - loss: 0.9069 - accuracy: 0.9940 - val_loss: 1.2163 - val_accuracy: 0.8357 - lr: 1.0000e-03
# Epoch 78/120
# 391/391 [==============================] - 19s 48ms/step - loss: 0.9052 - accuracy: 0.9948 - val_loss: 1.2062 - val_accuracy: 0.8411 - lr: 1.0000e-03
# Epoch 79/120
# 391/391 [==============================] - 19s 49ms/step - loss: 0.9035 - accuracy: 0.9954 - val_loss: 1.2140 - val_accuracy: 0.8361 - lr: 1.0000e-03
# Epoch 80/120
# 1026/1026 [==============================] - 5s 5ms/step
# 391/391 [==============================] - 26s 66ms/step - loss: 0.9038 - accuracy: 0.9943 - val_loss: 1.2031 - val_accuracy: 0.8422 - lr: 1.0000e-03 - pruning_ratio: 0.1000 - num_examples_pruned: 3280.0000
# Epoch 81/120
# 391/391 [==============================] - 18s 46ms/step - loss: 0.9007 - accuracy: 0.9954 - val_loss: 1.2053 - val_accuracy: 0.8394 - lr: 1.0000e-04
# Epoch 82/120
# 391/391 [==============================] - 18s 45ms/step - loss: 0.8987 - accuracy: 0.9965 - val_loss: 1.2047 - val_accuracy: 0.8397 - lr: 1.0000e-04
# Epoch 83/120
# 391/391 [==============================] - 18s 45ms/step - loss: 0.8989 - accuracy: 0.9964 - val_loss: 1.2045 - val_accuracy: 0.8403 - lr: 1.0000e-04
# Epoch 84/120
# 391/391 [==============================] - 17s 44ms/step - loss: 0.8992 - accuracy: 0.9963 - val_loss: 1.2041 - val_accuracy: 0.8399 - lr: 1.0000e-04
# Epoch 85/120
# 133/391 [=========>....................] - ETA: 16s - loss: 0.8992 - accuracy: 0.9959

# %%
print(metadata)
print(len(images))
correct, incorrect = getCorrectSample(images)
print(len(correct))
print(len(incorrect))
showSample(correct, 16)
showSample(incorrect, 16)

# %%
#metadata = {'val accuracy': [91.36666655540466, 93.7166690826416, 94.23333406448364, 94.81666684150696, 95.45000195503235, 96.31666541099548, 96.78333401679993, 96.14999890327454], 'val loss': [0.9319291114807129, 0.5999569892883301, 0.36166685819625854, 0.21822355687618256, 0.17234396934509277, 0.12887966632843018, 0.11454400420188904, 0.13207554817199707], 'dataset accuracy before': [50.59259259259259, 49.407407407407405, 66.4074074074074, 66.77407407407408, 91.40370370370371, 91.35185185185185, 95.64444444444445, 96.08148148148148], 'dataset accuracy after': [57.733333333333334, 75.44814814814815, 89.22592592592594, 93.52962962962962, 95.25925925925925, 96.46666666666667, 96.57777777777777, 96.87037037037037], 'dataset correct relabelling': [7.151851851851852, 26.185185185185183, 23.18148148148148, 27.48888888888889, 4.588888888888889, 5.774074074074074, 1.5962962962962963, 1.6481481481481481], 'dataset incorrect relabelling': [0.011111111111111112, 0.14444444444444443, 0.362962962962963, 0.7333333333333333, 0.7333333333333333, 0.6592592592592592, 0.662962962962963, 0.8592592592592593], 'total dataset accuracy': [53.57037037037037, 66.59074074074074, 78.0, 91.37777777777778, 93.30555555555556, 95.86296296296297, 96.32962962962964, 96.72407407407407]} # Remove me

# %%
displayGraph(metadata)

# %%
print(labels)

# %%
images = getImages()
images = random.sample(images, 10000)
print("found", len(images), "images!")
images, val_images = splitTrainVal(images, 0.1)
#showSample(images, 16)
#showSample(val_images, 16)
images, changes = swapLabels(images, 0.5)
print("Labeling accuracy at start:", getLabelingAccuracy(images))
#showSample(changes, 16)

model, images1, metadata = trainEpochs(copy.deepcopy(images), MAIN_EPOCHS, verbose = 1)

displayGraph(metadata)

model1, images1, metadata1 = trainEpochs(copy.deepcopy(images), MAIN_EPOCHS, verbose = 1, mode="delete")

displayGraph(metadata1)
print(metadatalist)

# %%
for metadata in metadatalist:
  displayGraph(metadata)
